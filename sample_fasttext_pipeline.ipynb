# %%
import inspect
from azureml.core import Workspace, Dataset
from azureml.core.compute import AmlCompute, ComputeTarget
from azureml.pipeline.core.graph import DataType
from azureml.pipeline.wrapper import Module, dsl, Pipeline

# %%
subscription_id = '4f455bd0-f95a-4b7d-8d08-078611508e0b'
resource_group = 'fundamental'
workspace_name = 'fundamental2' # use another workspace

namespace=workspace_name # for loading module

workspace = Workspace(subscription_id, resource_group, workspace_name)
print(workspace.name, workspace.resource_group, workspace.location, workspace.subscription_id, workspace.compute_targets.keys(),sep = '\n')
# Out:
# fundamental2
# fundamental
# eastasia
# 4f455bd0-f95a-4b7d-8d08-078611508e0b
# dict_keys(['aml-compute', 'aml-compute2'])

# %%
print(workspace.compute_targets)
aml_compute_name = 'aml-compute'
try:
    aml_compute = AmlCompute(workspace, aml_compute_name)
    print("Found existing compute target: {}".format(aml_compute_name))
except:
    print("Creating new compute target: {}".format(aml_compute_name))

    provisioning_config = AmlCompute.provisioning_configuration(vm_size="STANDARD_D2_V2",
                                                                min_nodes=1,
                                                                max_nodes=4)
    aml_compute = ComputeTarget.create(workspace, aml_compute_name, provisioning_config)
    aml_compute.wait_for_completion(show_output=True, min_node_count=None, timeout_in_minutes=20)
print(aml_compute)
# Out:
# {'aml-compute': AmlCompute(workspace=Workspace.create(name='fundamental2', subscription_id='4f455bd0-f95a-4b7d-8d08-078611508e0b', resource_group='fundamental'), name=aml-compute, id=/subscriptions/4f455bd0-f95a-4b7d-8d08-078611508e0b/resourceGroups/fundamental/providers/Microsoft.MachineLearningServices/workspaces/fundamental2/computes/aml-compute, type=AmlCompute, provisioning_state=Succeeded, location=eastasia, tags=None), 'aml-compute2': AmlCompute(workspace=Workspace.create(name='fundamental2', subscription_id='4f455bd0-f95a-4b7d-8d08-078611508e0b', resource_group='fundamental'), name=aml-compute2, id=/subscriptions/4f455bd0-f95a-4b7d-8d08-078611508e0b/resourceGroups/fundamental/providers/Microsoft.MachineLearningServices/workspaces/fundamental2/computes/aml-compute2, type=AmlCompute, provisioning_state=Succeeded, location=eastasia, tags=None)}
# Found existing compute target: aml-compute
# AmlCompute(workspace=Workspace.create(name='fundamental2', subscription_id='4f455bd0-f95a-4b7d-8d08-078611508e0b', resource_group='fundamental'), name=aml-compute, id=/subscriptions/4f455bd0-f95a-4b7d-8d08-078611508e0b/resourceGroups/fundamental/providers/Microsoft.MachineLearningServices/workspaces/fundamental2/computes/aml-compute, type=AmlCompute, provisioning_state=Succeeded, location=eastasia, tags=None)

# %%
# register my own datatype
DataType.create_data_type(workspace, 'MyDirectory', description='', is_directory=True) # won't register repeatedly
DataType.create_data_type(workspace, 'MyFile', description='', is_directory=False)

# %%
# load data
dataset_name = 'THUCNews_TXT'
char2index_name = 'Char2Index_JSON'

if dataset_name not in workspace.datasets:
    print('Registering a THUCNews dataset for fasttext pipeline ...')
    path = ['https://datastore4fasttext.blob.core.windows.net/mytest3/THUCNews.txt']
    data = Dataset.File.from_files(path=path)
    data.register(workspace=workspace, name=dataset_name, description='THUCNews dataset is generated by filtering and filtering historical data of Sina News RSS subscription channel from 2005 to 2011')
    print('Registerd')
data = workspace.datasets[dataset_name]

if char2index_name not in workspace.datasets:
    print('Registering a Char2Index_JSON for fasttext pipeline ...')
    path = ['https://datastore4fasttext.blob.core.windows.net/mytest3/character2index.json']
    data = Dataset.File.from_files(path=path)
    data.register(workspace=workspace, name=char2index_name, description='The mapping relationship between character and index ')
    print('Registerd')
char2index = workspace.datasets[char2index_name]

print(data)
print(char2index)
# Out:
# FileDataset
# {
#   "source": [
#     "https://datastore4fasttext.blob.core.windows.net/mytest3/THUCNews.txt"
#   ],
#   "definition": [
#     "GetFiles"
#   ],
#   "registration": {
#     "id": "0a805b2d-f748-49a7-94a9-be849144332f",
#     "name": "THUCNews_TXT",
#     "version": 1,
#     "description": "THUCNews dataset is generated by filtering and filtering historical data of Sina News RSS subscription channel from 2005 to 2011",
#     "workspace": "Workspace.create(name='fundamental2', subscription_id='4f455bd0-f95a-4b7d-8d08-078611508e0b', resource_group='fundamental')"
#   }
# }
# FileDataset
# {
#   "source": [
#     "https://datastore4fasttext.blob.core.windows.net/mytest3/character2index.json"
#   ],
#   "definition": [
#     "GetFiles"
#   ],
#   "registration": {
#     "id": "d2b97358-08d5-4428-b17e-559cf3a3de9b",
#     "name": "Char2Index_JSON",
#     "version": 1,
#     "description": "The mapping relationship between character and index ",
#     "workspace": "Workspace.create(name='fundamental2', subscription_id='4f455bd0-f95a-4b7d-8d08-078611508e0b', resource_group='fundamental')"
#   }
# }

# %%
# load module
try:
    split_data_txt_module_func = Module.load(workspace=workspace, namespace=namespace, name='Split Data Txt')
    print('found split_data_txt_module')
except:
    print('not found split_data_txt_module, register it now...')
    yaml_file='split_data_txt.spec.yaml'
    split_data_txt_module_func = Module.register(workspace=workspace, yaml_file=yaml_file)

try:
    fasttext_train_module_func = Module.load(workspace=workspace, namespace=namespace, name='FastText Train')
    print('found fasttext_train_module')
except:
    print('not found fasttext_train_module, register it now...')
    yaml_file='fasttext_train.spec.yaml'
    fasttext_train_module_func = Module.register(workspace=workspace, yaml_file=yaml_file)

try:
    fasttext_test_module_func = Module.load(workspace=workspace, namespace=namespace, name='FastText Test')
    print('found fasttext_test_module')
except:
    print('not found fasttext_test_module, register it now...')
    yaml_file='fasttext_test.spec.yaml'
    fasttext_test_module_func = Module.register(workspace=workspace, yaml_file=yaml_file)
# inspect signature
print(inspect.signature(split_data_txt_module_func))
print(inspect.signature(fasttext_train_module_func))
print(inspect.signature(fasttext_test_module_func))
# Out:
# found split_data_txt_module
# found fasttext_train_module
# found fasttext_test_module
# (input_dir:'Input Dir'=None, training_data_ratio:'Training Data Ratio'='0.7', validation_data_ratio:'Validation Data Ratio'='0.1', random_split:'Random Split'='False', seed:'Seed'='0')
# (training_data_dir:'Training Data Dir'=None, validation_data_dir:'Validation Data Dir'=None, char2_index_dir:'Char2Index Dir'=None, epochs:'Epochs'='2', batch_size:'Batch Size'='32', learning_rate:'Learning Rate'='0.0005', embedding_dim:'Embedding Dim'='128')
# (trained_model_dir:'Trained Model Dir'=None, test_data_dir:'Test Data Dir'=None, char2_index_dir:'Char2Index Dir'=None)

# %%
# connect module
split_data_txt = split_data_txt_module_func(
    input_dir = data,
    training_data_ratio = 0.7,
    validation_data_ratio = 0.1,
    random_split = False,
    seed = 1
)
print(split_data_txt.outputs)

fasttext_train = fasttext_train_module_func(
    training_data_dir = split_data_txt.outputs.training_data_output,
    validation_data_dir = split_data_txt.outputs.validation_data_output,
    char2_index_dir = char2index,
    epochs = 1,
    batch_size = 64,
    learning_rate = 0.0005,
    embedding_dim = 128
)
print(fasttext_train.outputs)

fasttext_test = fasttext_test_module_func(
    trained_model_dir = fasttext_train.outputs.trained_model_dir,
    test_data_dir = split_data_txt.outputs.test_data_output,
    char2_index_dir = char2index
)
# Out:
# {'training_data_output': <azureml.pipeline.wrapper._module._OutputBuilder object at 0x000001F4D1DEBA20>, 'validation_data_output': <azureml.pipeline.wrapper._module._OutputBuilder object at 0x000001F4D1DEBC88>, 'test_data_output': <azureml.pipeline.wrapper._module._OutputBuilder object at 0x000001F4D1DEB8D0>}
# {'trained_model_dir': <azureml.pipeline.wrapper._module._OutputBuilder object at 0x000001F4D1D857F0>}

# %%
# pipeline
pipeline = Pipeline(nodes=[split_data_txt, fasttext_train, fasttext_test], workspace=workspace, default_compute_target=aml_compute_name)

# %%
# validate
pipeline.validate()
# Out:
# SupportDetectView()
#         <style>
#         #container_id_84891cb5-5c34-4e45-a7a0-68a72d724d46 svg.react-dag-editor-svg-container {
#             height: 800px;
#         }
#         </style>
#         <div id="container_id_84891cb5-5c34-4e45-a7a0-68a72d724d46"></div>
#         <script>
#             window.render_container_id="container_id_84891cb5-5c34-4e45-a7a0-68a72d724d46";
#             window.graph_json={"pipeline": {"name": "Pipeline-Created-on-6-17-2020", "data_references": {"THUCNews_TXT": {"dataset_id": "de4be02d-68e8-42c5-aaf7-a8576e74784e"}, "Char2Index_JSON": {"dataset_id": "b8bbbf95-2f58-475e-ab23-8b8cd11b9d59"}}, "steps": {"8d9ac7c9-a1f9-4349-8b95-5f5fbf76fa81": {"inputs": {"Input_Dir": {"source": "THUCNews_TXT"}}, "outputs": {"Training_Data_Output": {"destination": "8d9ac7c9-a1f9-4349-8b95-5f5fbf76fa81_Training_Data_Output"}, "Validation_Data_Output": {"destination": "8d9ac7c9-a1f9-4349-8b95-5f5fbf76fa81_Validation_Data_Output"}, "Test_Data_Output": {"destination": "8d9ac7c9-a1f9-4349-8b95-5f5fbf76fa81_Test_Data_Output"}}, "module": {"id": "da551e74-65cf-43ee-9dfe-80a62b9d7e70", "version": "0.0.3"}, "validate": {"error": [], "module_id": "da551e74-65cf-43ee-9dfe-80a62b9d7e70", "namespace": "fundamental2", "module_name": "Split Data Txt", "module_version": "0.0.3"}}, "641a4c47-d765-4718-858f-b4c5056e81d4": {"inputs": {"Char2_Index_Dir": {"source": "Char2Index_JSON"}, "Validation_Data_Dir": {"source": "8d9ac7c9-a1f9-4349-8b95-5f5fbf76fa81_Validation_Data_Output"}, "Training_Data_Dir": {"source": "8d9ac7c9-a1f9-4349-8b95-5f5fbf76fa81_Training_Data_Output"}}, "outputs": {"Trained_Model_Dir": {"destination": "641a4c47-d765-4718-858f-b4c5056e81d4_Trained_Model_Dir"}}, "module": {"id": "ee25dbf3-bea7-4c8a-9138-ec86a0b9376d", "version": "0.0.8"}, "validate": {"error": [], "module_id": "ee25dbf3-bea7-4c8a-9138-ec86a0b9376d", "namespace": "fundamental2", "module_name": "FastText Train", "module_version": "0.0.8"}}, "cc57792c-ca0c-4e09-897e-b66d47c68425": {"inputs": {"Char2_Index_Dir": {"source": "Char2Index_JSON"}, "Test_Data_Dir": {"source": "8d9ac7c9-a1f9-4349-8b95-5f5fbf76fa81_Test_Data_Output"}, "Trained_Model_Dir": {"source": "641a4c47-d765-4718-858f-b4c5056e81d4_Trained_Model_Dir"}}, "outputs": {}, "module": {"id": "bfd5db50-24fc-4248-837c-7205006bc4a4", "version": "0.0.7"}, "validate": {"error": [], "module_id": "bfd5db50-24fc-4248-837c-7205006bc4a4", "namespace": "fundamental2", "module_name": "FastText Test", "module_version": "0.0.7"}}}}, "subGraphInfo": [{"name": "Pipeline-Created-on-6-17-2020", "description": null, "defaultCompute": "aml-compute", "id": "1a052cf0-56b9-4939-bac0-266966337bb8", "parentGraphId": null, "inputs": [{"name": "THUCNews_TXT_8d9ac7c9-a1f9-4349-8b95-5f5fbf76fa81", "external": [], "internal": [{"portName": "Input_Dir", "nodeId": "8d9ac7c9-a1f9-4349-8b95-5f5fbf76fa81"}]}, {"name": "Char2Index_JSON_641a4c47-d765-4718-858f-b4c5056e81d4", "external": [], "internal": [{"portName": "Char2_Index_Dir", "nodeId": "641a4c47-d765-4718-858f-b4c5056e81d4"}]}, {"name": "Char2Index_JSON_cc57792c-ca0c-4e09-897e-b66d47c68425", "external": [], "internal": [{"portName": "Char2_Index_Dir", "nodeId": "cc57792c-ca0c-4e09-897e-b66d47c68425"}]}], "outputs": []}], "nodeIdToSubGraphIdMapping": {"8d9ac7c9-a1f9-4349-8b95-5f5fbf76fa81": "1a052cf0-56b9-4939-bac0-266966337bb8", "641a4c47-d765-4718-858f-b4c5056e81d4": "1a052cf0-56b9-4939-bac0-266966337bb8", "cc57792c-ca0c-4e09-897e-b66d47c68425": "1a052cf0-56b9-4939-bac0-266966337bb8"}, "modules": [{"module_id": "da551e74-65cf-43ee-9dfe-80a62b9d7e70", "version": "0.0.3", "name": "Split Data Txt", "namespace": "fundamental2", "structured_interface": {"inputs": [{"name": "Input_Dir", "label": "Input Dir", "description": null}], "outputs": [{"name": "Training_Data_Output", "label": "Training Data Output", "description": null}, {"name": "Validation_Data_Output", "label": "Validation Data Output", "description": null}, {"name": "Test_Data_Output", "label": "Test Data Output", "description": null}]}}, {"module_id": "ee25dbf3-bea7-4c8a-9138-ec86a0b9376d", "version": "0.0.8", "name": "FastText Train", "namespace": "fundamental2", "structured_interface": {"inputs": [{"name": "Training_Data_Dir", "label": "Training Data Dir", "description": null}, {"name": "Validation_Data_Dir", "label": "Validation Data Dir", "description": null}, {"name": "Char2_Index_ ...
#             window.env_json={"subscription_id": "4f455bd0-f95a-4b7d-8d08-078611508e0b"};
#             window.before_script = performance.now();
#         </script>
#         <script src="https://yucongj.azureedge.net/libs/prod/0.0.2/index.js"></script>
# {'result': 'validation passed', 'errors': []}

# %%
# run
run = pipeline.submit(experiment_name='fasttext_test')
run.wait_for_completion()
pipeline.save(experiment_name='fasttext_test')
# Out:
# vfVJpax4bk6BiyIl47eco%2Bc%2Fq60AbYcbL0%3D&st=2020-06-17T09%3A12%3A56Z&se=2020-06-17T17%3A22%3A56Z&sp=r', 'azureml-logs/75_job_post-tvmps_0e5b20827f3ec455d9622f3716ef6ecba3723f15ab0c6630ee1b90283621397b_d.txt': 'https://fundamental29908941189.blob.core.windows.net/azureml/ExperimentRun/dcid.84d4c61b-7adf-429a-af0d-ed2cf2f9096c/azureml-logs/75_job_post-tvmps_0e5b20827f3ec455d9622f3716ef6ecba3723f15ab0c6630ee1b90283621397b_d.txt?sv=2019-02-02&sr=b&sig=Ah%2Fq9OaTPIQMinoKOux%2F49ArA7bjQdflqqwms%2FQlx8I%3D&st=2020-06-17T09%3A12%3A56Z&se=2020-06-17T17%3A22%3A56Z&sp=r', 'azureml-logs/process_info.json': 'https://fundamental29908941189.blob.core.windows.net/azureml/ExperimentRun/dcid.84d4c61b-7adf-429a-af0d-ed2cf2f9096c/azureml-logs/process_info.json?sv=2019-02-02&sr=b&sig=LuX9pvuGT9mqh3YLkP8S8h1lfCbX0UbDqT0FfBFqb%2Bw%3D&st=2020-06-17T09%3A12%3A56Z&se=2020-06-17T17%3A22%3A56Z&sp=r', 'azureml-logs/process_status.json': 'https://fundamental29908941189.blob.core.windows.net/azureml/ExperimentRun/dcid.84d4c61b-7adf-429a-af0d-ed2cf2f9096c/azureml-logs/process_status.json?sv=2019-02-02&sr=b&sig=cENosmSbl2uFRhAg31sw5bhMog%2BQgaJf22INc5CRaPQ%3D&st=2020-06-17T09%3A12%3A56Z&se=2020-06-17T17%3A22%3A56Z&sp=r', 'logs/azureml/executionlogs.txt': 'https://fundamental29908941189.blob.core.windows.net/azureml/ExperimentRun/dcid.84d4c61b-7adf-429a-af0d-ed2cf2f9096c/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=LbO6G3%2BM0KVl%2B6dQl%2BAKPgVe0qtG3QERH107ceS%2F4k0%3D&st=2020-06-17T09%3A12%3A56Z&se=2020-06-17T17%3A22%3A56Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://fundamental29908941189.blob.core.windows.net/azureml/ExperimentRun/dcid.84d4c61b-7adf-429a-af0d-ed2cf2f9096c/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=%2B7hK9OF0CpZwcPSRKcJTcohhD0f2gXTirC8gGPwxMrE%3D&st=2020-06-17T09%3A12%3A56Z&se=2020-06-17T17%3A22%3A56Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://fundamental29908941189.blob.core.windows.net/azureml/ExperimentRun/dcid.84d4c61b-7adf-429a-af0d-ed2cf2f9096c/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=0HpajHxeILGoNYwt7%2By%2FrRVPJlx6PWZwJKMJvn1QWuE%3D&st=2020-06-17T09%3A12%3A56Z&se=2020-06-17T17%3A22%3A56Z&sp=r'}}
#
#
#
#
# StepRunId: 4fdc3a74-e484-4c5f-a323-b829fd950db1
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/fasttext_test/runs/4fdc3a74-e484-4c5f-a323-b829fd950db1?wsid=/subscriptions/4f455bd0-f95a-4b7d-8d08-078611508e0b/resourcegroups/fundamental/workspaces/fundamental2
#
# StepRun(FastText Train) Execution Summary
# ==========================================
# StepRun( FastText Train ) Status: Completed
# {'runId': '4fdc3a74-e484-4c5f-a323-b829fd950db1', 'target': 'aml-compute', 'status': 'Completed', 'startTimeUtc': '2020-06-17T09:22:54.282582Z', 'endTimeUtc': '2020-06-17T09:22:54.351697Z', 'properties': {'azureml.reusedrunid': '3509b4ef-00ee-46c7-957e-82ebf251d558', 'azureml.reusednodeid': 'aa5b59a4', 'azureml.reusedpipeline': '40475475-56b4-44eb-8eda-b668ae723a49', 'azureml.reusedpipelinerunid': '40475475-56b4-44eb-8eda-b668ae723a49', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'f95327f9', 'ContentSnapshotId': '52314070-ac74-475a-8534-93be20d6dab0', 'StepType': 'PythonScriptStep', 'azureml.moduleid': 'ee25dbf3-bea7-4c8a-9138-ec86a0b9376d', 'azureml.pipelinerunid': '0f67a6eb-dbfc-4161-8535-81c02676f290', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'runDefinition': {'script': 'fasttext_train.py', 'useAbsolutePath': False, 'arguments': ['--training_data_dir', '$AZUREML_DATAREFERENCE_Training_Data_Dir', '--validation_data_dir', '$AZUREML_DATAREFERENCE_Validation_Data_Dir', '--char2index_dir', '$AZUREML_DATAREFERENCE_Char2_Index_Dir', '--epochs', '$AZUREML_PARAMETER_Epochs', '--batch_size', '$AZUREML_PARAMETER_Batch_Size', '--learning_rate', '$AZUREML_PARAMETER_Learning_Rate', '--embedding_dim', '$AZUREML_PARAMETER_Embedding_Dim', '--trained_model_dir', '$AZUREML_DATAREFERENCE_Trained_Model_Dir'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'aml-compute', 'dataReferences': {'Training_Data_Dir': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/802c1886-dc73-448f-aae8-43eeec0d99d9/Training_Data_Output', 'pathOnCompute': None, 'overwrite': True}, 'Validation_Data_Dir': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/802c1886-dc73-448f-aae8-43eeec0d99d9/Validation_Data_Output', 'pathOnCompute': None, 'overwrite': True}, 'Trained_Model_Dir': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/3509b4ef-00ee-46c7-957e-82ebf251d558/Trained_Model_Dir', 'pathOnCompute': None, 'overwrite': True}}, 'data': {'Char2_Index_Dir': {'dataLocation': {'dataset': {'id': 'd2b97358-08d5-4428-b17e-559cf3a3de9b', 'name': None, 'version': None}, 'dataPath': None}, 'mechanism': 'Mount', 'environmentVariableName': 'Char2_Index_Dir', 'pathOnCompute': None, 'overwrite': True}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'Experiment fasttext_test Environment', 'version': 'Autosave_2020-06-17T08:52:42Z_79f6cd52', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['defaults'], 'dependencies': ['python=3.6.6', {'pip': ['--extra-index-url=https://azuremlsdktestpypi.azureedge.net/CLI-SDK-Runners-Validation/15587761', 'azureml-defaults==0.1.0.15587761', 'azureml-pipeline-wrapper==0.1.0.15587761', 'torch==1.4.0', 'scikit-learn', 'tqdm']}], 'name': 'azureml_bfe9579f8051e70e1e6a7a7f61593161'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'AZUREML_PARAMETER_Epochs': '1', 'AZUREML_PARAMETER_Batch_Size': '64', 'AZUREML_PARAMETER_Learning_Rate': '0.0005', 'AZUREML_PARAMETER_Embedding_Dim': '128'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'sharedVolumes': False, 'shmSize': '1g'}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': False, 'directoriesToWatch': ['logs']}, 'spark': {'configuration': {}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize':  ...
#
#
#
#
# StepRunId: ec66e6e6-96ec-44a0-91be-445634aa5a89
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/fasttext_test/runs/ec66e6e6-96ec-44a0-91be-445634aa5a89?wsid=/subscriptions/4f455bd0-f95a-4b7d-8d08-078611508e0b/resourcegroups/fundamental/workspaces/fundamental2
#
# StepRun(Split Data Txt) Execution Summary
# ==========================================
# StepRun( Split Data Txt ) Status: Completed
# {'runId': 'ec66e6e6-96ec-44a0-91be-445634aa5a89', 'target': 'aml-compute', 'status': 'Completed', 'startTimeUtc': '2020-06-17T09:22:53.785042Z', 'endTimeUtc': '2020-06-17T09:22:53.850517Z', 'properties': {'azureml.reusedrunid': '802c1886-dc73-448f-aae8-43eeec0d99d9', 'azureml.reusednodeid': '71eaf88c', 'azureml.reusedpipeline': '40475475-56b4-44eb-8eda-b668ae723a49', 'azureml.reusedpipelinerunid': '40475475-56b4-44eb-8eda-b668ae723a49', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '0a00fff3', 'ContentSnapshotId': 'b3e43a21-1ff2-44e9-88d5-42bc060b5f06', 'StepType': 'PythonScriptStep', 'azureml.moduleid': 'da551e74-65cf-43ee-9dfe-80a62b9d7e70', 'azureml.pipelinerunid': '0f67a6eb-dbfc-4161-8535-81c02676f290', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'runDefinition': {'script': 'split_data_txt.py', 'useAbsolutePath': False, 'arguments': ['--input_dir', '$AZUREML_DATAREFERENCE_Input_Dir', '--training_data_ratio', '$AZUREML_PARAMETER_Training_Data_Ratio', '--validation_data_ratio', '$AZUREML_PARAMETER_Validation_Data_Ratio', '--random_split', '$AZUREML_PARAMETER_Random_Split', '--seed', '$AZUREML_PARAMETER_Seed', '--training_data_output', '$AZUREML_DATAREFERENCE_Training_Data_Output', '--validation_data_output', '$AZUREML_DATAREFERENCE_Validation_Data_Output', '--test_data_output', '$AZUREML_DATAREFERENCE_Test_Data_Output'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'aml-compute', 'dataReferences': {'Training_Data_Output': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/802c1886-dc73-448f-aae8-43eeec0d99d9/Training_Data_Output', 'pathOnCompute': None, 'overwrite': True}, 'Validation_Data_Output': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/802c1886-dc73-448f-aae8-43eeec0d99d9/Validation_Data_Output', 'pathOnCompute': None, 'overwrite': True}, 'Test_Data_Output': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/802c1886-dc73-448f-aae8-43eeec0d99d9/Test_Data_Output', 'pathOnCompute': None, 'overwrite': True}}, 'data': {'Input_Dir': {'dataLocation': {'dataset': {'id': '0a805b2d-f748-49a7-94a9-be849144332f', 'name': None, 'version': None}, 'dataPath': None}, 'mechanism': 'Mount', 'environmentVariableName': 'Input_Dir', 'pathOnCompute': None, 'overwrite': True}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'Experiment fasttext_test Environment', 'version': 'Autosave_2020-06-17T08:50:40Z_b081bd09', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['defaults'], 'dependencies': ['python=3.6.6', {'pip': ['--extra-index-url=https://azuremlsdktestpypi.azureedge.net/CLI-SDK-Runners-Validation/15587761', 'azureml-defaults==0.1.0.15587761', 'azureml-pipeline-wrapper==0.1.0.15587761', 'torch==1.4.0', 'scikit-learn', 'tqdm']}], 'name': 'azureml_bfe9579f8051e70e1e6a7a7f61593161'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'AZUREML_PARAMETER_Training_Data_Ratio': '0.7', 'AZUREML_PARAMETER_Validation_Data_Ratio': '0.1', 'AZUREML_PARAMETER_Random_Split': 'False', 'AZUREML_PARAMETER_Seed': '1'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'sharedVolumes': False, 'shmSize': '1g'}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': False, 'directoriesToWatch': ['logs']}, 'spark': {'configuration': {}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCo ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Completed
# {'runId': '0f67a6eb-dbfc-4161-8535-81c02676f290', 'status': 'Completed', 'startTimeUtc': '2020-06-17T09:22:52.611334Z', 'endTimeUtc': '2020-06-17T09:22:54.920524Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'Designer', 'runType': 'HTTP', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://fundamental29908941189.blob.core.windows.net/azureml/ExperimentRun/dcid.0f67a6eb-dbfc-4161-8535-81c02676f290/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=VWCKxGkWDwhqR6WUFQPrdWbNO%2FFwX%2BlhWd7vcIQbbSM%3D&st=2020-06-17T09%3A13%3A02Z&se=2020-06-17T17%3A23%3A02Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://fundamental29908941189.blob.core.windows.net/azureml/ExperimentRun/dcid.0f67a6eb-dbfc-4161-8535-81c02676f290/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=sPN8of7hVw9yNfz9fIRHb1ifgVAwUHACGyRMbY7hUfw%3D&st=2020-06-17T09%3A13%3A02Z&se=2020-06-17T17%3A23%3A02Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://fundamental29908941189.blob.core.windows.net/azureml/ExperimentRun/dcid.0f67a6eb-dbfc-4161-8535-81c02676f290/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=NlaJTPljoBefNowAbtoUb2Qralzg9OKhTCEHHRuD6rM%3D&st=2020-06-17T09%3A13%3A02Z&se=2020-06-17T17%3A23%3A02Z&sp=r'}}
# <table style="width:100%"><tr><th>Name</th><th>Id</th><th>Details page</th><th>Pipeline type</th><th>Updated on</th><th>Created by</th><th>Tags</th></tr><tr><td>Pipeline-Created-on-6-17-2020</td><td>b2ad2df4-643e-46a1-8366-89535caff476</td><td><a href="https://ml.azure.com/visualinterface/authoring/Normal/b2ad2df4-643e-46a1-8366-89535caff476?wsid=/subscriptions/4f455bd0-f95a-4b7d-8d08-078611508e0b/resourcegroups/fundamental/workspaces/fundamental2" target="_blank" rel="noopener">Link</a></td><td>TrainingPipeline</td><td>June 17, 2020 05:23 PM</td><td>Xiaoyu Yang</td><td><table style="width:100%"><tr><td>azureml.Designer: true</td></tr></table></td></tr></table>
