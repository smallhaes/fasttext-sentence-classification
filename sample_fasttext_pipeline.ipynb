# %%
import inspect
from azureml.core import Workspace, Dataset
from azureml.core.compute import AmlCompute, ComputeTarget
from azureml.pipeline.core.graph import DataType
from azureml.pipeline.wrapper import Module, dsl, Pipeline

# %%
subscription_id = '4f455bd0-f95a-4b7d-8d08-078611508e0b'
resource_group = 'fundamental'
workspace_name = 'fundamental3' # use another workspace

namespace=workspace_name # for loading module

workspace = Workspace(subscription_id, resource_group, workspace_name)
print(workspace.name, workspace.resource_group, workspace.location, workspace.subscription_id, workspace.compute_targets.keys(),sep = '\n')
# Out:
# fundamental3
# fundamental
# eastasia
# 4f455bd0-f95a-4b7d-8d08-078611508e0b
# dict_keys(['aml-compute'])

# %%
print(workspace.compute_targets)
aml_compute_name = 'aml-compute'
try:
    aml_compute = AmlCompute(workspace, aml_compute_name)
    print("Found existing compute target: {}".format(aml_compute_name))
except:
    print("Creating new compute target: {}".format(aml_compute_name))

    provisioning_config = AmlCompute.provisioning_configuration(vm_size="STANDARD_D2_V2",
                                                                min_nodes=1,
                                                                max_nodes=4)
    aml_compute = ComputeTarget.create(workspace, aml_compute_name, provisioning_config)
    aml_compute.wait_for_completion(show_output=True, min_node_count=None, timeout_in_minutes=20)
print(aml_compute)
# Out:
# {'aml-compute': AmlCompute(workspace=Workspace.create(name='fundamental3', subscription_id='4f455bd0-f95a-4b7d-8d08-078611508e0b', resource_group='fundamental'), name=aml-compute, id=/subscriptions/4f455bd0-f95a-4b7d-8d08-078611508e0b/resourceGroups/fundamental/providers/Microsoft.MachineLearningServices/workspaces/fundamental3/computes/aml-compute, type=AmlCompute, provisioning_state=Succeeded, location=eastasia, tags=None)}
# Found existing compute target: aml-compute
# AmlCompute(workspace=Workspace.create(name='fundamental3', subscription_id='4f455bd0-f95a-4b7d-8d08-078611508e0b', resource_group='fundamental'), name=aml-compute, id=/subscriptions/4f455bd0-f95a-4b7d-8d08-078611508e0b/resourceGroups/fundamental/providers/Microsoft.MachineLearningServices/workspaces/fundamental3/computes/aml-compute, type=AmlCompute, provisioning_state=Succeeded, location=eastasia, tags=None)

# %%
# register my own datatype
DataType.create_data_type(workspace, 'MyDirectory', description='', is_directory=True) # won't register repeatedly
DataType.create_data_type(workspace, 'MyFile', description='', is_directory=False)

# %%
# load data
dataset_name = 'THUCNews_TXT'
char2index_name = 'Char2Index_JSON'

if dataset_name not in workspace.datasets:
    print('Registering a THUCNews dataset for fasttext pipeline ...')
    path = ['https://datastore4fasttext.blob.core.windows.net/mytest3/THUCNews.txt']
    data = Dataset.File.from_files(path=path)
    data.register(workspace=workspace, name=dataset_name, description='THUCNews dataset is generated by filtering and filtering historical data of Sina News RSS subscription channel from 2005 to 2011')
    print('Registerd')
data = workspace.datasets[dataset_name]

if char2index_name not in workspace.datasets:
    print('Registering a Char2Index_JSON for fasttext pipeline ...')
    path = ['https://datastore4fasttext.blob.core.windows.net/mytest3/character2index.json']
    data = Dataset.File.from_files(path=path)
    data.register(workspace=workspace, name=char2index_name, description='The mapping relationship between character and index ')
    print('Registerd')
char2index = workspace.datasets[char2index_name]

print(data)
print(char2index)
# Out:
# FileDataset
# {
#   "source": [
#     "https://datastore4fasttext.blob.core.windows.net/mytest3/THUCNews.txt"
#   ],
#   "definition": [
#     "GetFiles"
#   ],
#   "registration": {
#     "id": "9e16ea04-3074-4f84-8a8c-83adb226c4ae",
#     "name": "THUCNews_TXT",
#     "version": 1,
#     "description": "THUCNews dataset is generated by filtering and filtering historical data of Sina News RSS subscription channel from 2005 to 2011",
#     "workspace": "Workspace.create(name='fundamental3', subscription_id='4f455bd0-f95a-4b7d-8d08-078611508e0b', resource_group='fundamental')"
#   }
# }
# FileDataset
# {
#   "source": [
#     "https://datastore4fasttext.blob.core.windows.net/mytest3/character2index.json"
#   ],
#   "definition": [
#     "GetFiles"
#   ],
#   "registration": {
#     "id": "9de9b550-46a4-41ce-b1b4-54b6c665fcf3",
#     "name": "Char2Index_JSON",
#     "version": 1,
#     "description": "The mapping relationship between character and index ",
#     "workspace": "Workspace.create(name='fundamental3', subscription_id='4f455bd0-f95a-4b7d-8d08-078611508e0b', resource_group='fundamental')"
#   }
# }

# %%
# load module
try:
    split_data_txt_module_func = Module.load(workspace=workspace, namespace=namespace, name='Split Data Txt')
    print('found split_data_txt_module')
except:
    print('not found split_data_txt_module, register it now...')
    yaml_file='split_data_txt/split_data_txt.spec.yaml'
    split_data_txt_module_func = Module.register(workspace=workspace, yaml_file=yaml_file)

try:
    fasttext_train_module_func = Module.load(workspace=workspace, namespace=namespace, name='FastText Train')
    print('found fasttext_train_module')
except:
    print('not found fasttext_train_module, register it now...')
    yaml_file='fasttext_train/fasttext_train.spec.yaml'
    fasttext_train_module_func = Module.register(workspace=workspace, yaml_file=yaml_file)

try:
    fasttext_test_module_func = Module.load(workspace=workspace, namespace=namespace, name='FastText Test')
    print('found fasttext_test_module')
except:
    print('not found fasttext_test_module, register it now...')
    yaml_file='fasttext_test/fasttext_test.spec.yaml'
    fasttext_test_module_func = Module.register(workspace=workspace, yaml_file=yaml_file)
# inspect signature
print(inspect.signature(split_data_txt_module_func))
print(inspect.signature(fasttext_train_module_func))
print(inspect.signature(fasttext_test_module_func))
# Out:
# found split_data_txt_module
# found fasttext_train_module
# found fasttext_test_module
# (input_dir:'Input Dir'=None, training_data_ratio:'Training Data Ratio'='0.7', validation_data_ratio:'Validation Data Ratio'='0.1', random_split:'Random Split'='False', seed:'Seed'='0')
# (training_data_dir:'Training Data Dir'=None, validation_data_dir:'Validation Data Dir'=None, char2_index_dir:'Char2Index Dir'=None, epochs:'Epochs'='2', batch_size:'Batch Size'='32', learning_rate:'Learning Rate'='0.0005', embedding_dim:'Embedding Dim'='128')
# (trained_model_dir:'Trained Model Dir'=None, test_data_dir:'Test Data Dir'=None, char2_index_dir:'Char2Index Dir'=None)

# %%
# connect module
split_data_txt = split_data_txt_module_func(
    input_dir = data,
    training_data_ratio = 0.7,
    validation_data_ratio = 0.1,
    random_split = False,
    seed = 1
)
print(split_data_txt.outputs)

fasttext_train = fasttext_train_module_func(
    training_data_dir = split_data_txt.outputs.training_data_output,
    validation_data_dir = split_data_txt.outputs.validation_data_output,
    char2_index_dir = char2index,
    epochs = 1,
    batch_size = 64,
    learning_rate = 0.0005,
    embedding_dim = 128
)
print(fasttext_train.outputs)

fasttext_test = fasttext_test_module_func(
    trained_model_dir = fasttext_train.outputs.trained_model_dir,
    test_data_dir = split_data_txt.outputs.test_data_output,
    char2_index_dir = char2index
)
# Out:
# {'training_data_output': <azureml.pipeline.wrapper._module._OutputBuilder object at 0x7f634114f860>, 'validation_data_output': <azureml.pipeline.wrapper._module._OutputBuilder object at 0x7f634114f588>, 'test_data_output': <azureml.pipeline.wrapper._module._OutputBuilder object at 0x7f634114f630>}
# {'trained_model_dir': <azureml.pipeline.wrapper._module._OutputBuilder object at 0x7f6342e85160>}

# %%
# pipeline
pipeline = Pipeline(nodes=[split_data_txt, fasttext_train, fasttext_test], workspace=workspace, default_compute_target=aml_compute_name)

# %%
# validate
pipeline.validate()
# Out:
# SupportDetectView()
#         <style>
#         #container_id_cab3e4dd-f238-41b5-9cab-9962b89c100b svg.react-dag-editor-svg-container {
#             height: 800px;
#         }
#         </style>
#         <div id="container_id_cab3e4dd-f238-41b5-9cab-9962b89c100b"></div>
#         <script>
#             window.render_container_id="container_id_cab3e4dd-f238-41b5-9cab-9962b89c100b";
#             window.graph_json={"pipeline": {"name": "Pipeline-Created-on-6-21-2020", "data_references": {"THUCNews_TXT": {"dataset_id": "b2319b6a-338d-4788-adfe-d55ca1db06b7"}, "Char2Index_JSON": {"dataset_id": "01760799-3cea-4885-9d68-04bbd10e3bd9"}}, "steps": {"7541ee26-df1d-402c-bd3c-750189257100": {"inputs": {"Input_Dir": {"source": "THUCNews_TXT"}}, "outputs": {"Training_Data_Output": {"destination": "7541ee26-df1d-402c-bd3c-750189257100_Training_Data_Output"}, "Validation_Data_Output": {"destination": "7541ee26-df1d-402c-bd3c-750189257100_Validation_Data_Output"}, "Test_Data_Output": {"destination": "7541ee26-df1d-402c-bd3c-750189257100_Test_Data_Output"}}, "module": {"id": "5dc6384c-501b-490e-a0ca-5b7831af0e55", "version": "0.0.3"}, "validate": {"error": [], "module_id": "5dc6384c-501b-490e-a0ca-5b7831af0e55", "namespace": "fundamental3", "module_name": "Split Data Txt", "module_version": "0.0.3"}}, "70db4be5-2d18-4bcb-bb11-fcebe887cd52": {"inputs": {"Char2_Index_Dir": {"source": "Char2Index_JSON"}, "Validation_Data_Dir": {"source": "7541ee26-df1d-402c-bd3c-750189257100_Validation_Data_Output"}, "Training_Data_Dir": {"source": "7541ee26-df1d-402c-bd3c-750189257100_Training_Data_Output"}}, "outputs": {"Trained_Model_Dir": {"destination": "70db4be5-2d18-4bcb-bb11-fcebe887cd52_Trained_Model_Dir"}}, "module": {"id": "7d19f1e6-5357-41fa-a2a0-a36787f4bf63", "version": "0.0.8"}, "validate": {"error": [], "module_id": "7d19f1e6-5357-41fa-a2a0-a36787f4bf63", "namespace": "fundamental3", "module_name": "FastText Train", "module_version": "0.0.8"}}, "5346bee8-85ef-4bad-990b-85a176ea003f": {"inputs": {"Char2_Index_Dir": {"source": "Char2Index_JSON"}, "Test_Data_Dir": {"source": "7541ee26-df1d-402c-bd3c-750189257100_Test_Data_Output"}, "Trained_Model_Dir": {"source": "70db4be5-2d18-4bcb-bb11-fcebe887cd52_Trained_Model_Dir"}}, "outputs": {}, "module": {"id": "2bb4b42f-9da4-4ffa-b49d-0b8bb6d2af92", "version": "0.0.7"}, "validate": {"error": [], "module_id": "2bb4b42f-9da4-4ffa-b49d-0b8bb6d2af92", "namespace": "fundamental3", "module_name": "FastText Test", "module_version": "0.0.7"}}}}, "subGraphInfo": [{"name": "Pipeline-Created-on-6-21-2020", "description": null, "defaultCompute": "aml-compute", "id": "964a0d26-ce8b-45fa-8266-e2d0ef56a8b6", "parentGraphId": null, "inputs": [{"name": "THUCNews_TXT_7541ee26-df1d-402c-bd3c-750189257100", "external": [], "internal": [{"portName": "Input_Dir", "nodeId": "7541ee26-df1d-402c-bd3c-750189257100"}]}, {"name": "Char2Index_JSON_70db4be5-2d18-4bcb-bb11-fcebe887cd52", "external": [], "internal": [{"portName": "Char2_Index_Dir", "nodeId": "70db4be5-2d18-4bcb-bb11-fcebe887cd52"}]}, {"name": "Char2Index_JSON_5346bee8-85ef-4bad-990b-85a176ea003f", "external": [], "internal": [{"portName": "Char2_Index_Dir", "nodeId": "5346bee8-85ef-4bad-990b-85a176ea003f"}]}], "outputs": []}], "nodeIdToSubGraphIdMapping": {"7541ee26-df1d-402c-bd3c-750189257100": "964a0d26-ce8b-45fa-8266-e2d0ef56a8b6", "70db4be5-2d18-4bcb-bb11-fcebe887cd52": "964a0d26-ce8b-45fa-8266-e2d0ef56a8b6", "5346bee8-85ef-4bad-990b-85a176ea003f": "964a0d26-ce8b-45fa-8266-e2d0ef56a8b6"}, "modules": [{"module_id": "5dc6384c-501b-490e-a0ca-5b7831af0e55", "version": "0.0.3", "name": "Split Data Txt", "namespace": "fundamental3", "structured_interface": {"inputs": [{"name": "Input_Dir", "label": "Input Dir", "description": null}], "outputs": [{"name": "Training_Data_Output", "label": "Training Data Output", "description": null}, {"name": "Validation_Data_Output", "label": "Validation Data Output", "description": null}, {"name": "Test_Data_Output", "label": "Test Data Output", "description": null}]}}, {"module_id": "7d19f1e6-5357-41fa-a2a0-a36787f4bf63", "version": "0.0.8", "name": "FastText Train", "namespace": "fundamental3", "structured_interface": {"inputs": [{"name": "Training_Data_Dir", "label": "Training Data Dir", "description": null}, {"name": "Validation_Data_Dir", "label": "Validation Data Dir", "description": null}, {"name": "Char2_Index_ ...
#             window.env_json={"subscription_id": "4f455bd0-f95a-4b7d-8d08-078611508e0b"};
#             window.before_script = performance.now();
#         </script>
#         <script src="https://yucongj.azureedge.net/libs/prod/0.0.2/index.js"></script>
# {'result': 'validation passed', 'errors': []}

# %%
# run
run = pipeline.submit(experiment_name='fasttext_test')
run.wait_for_completion()
pipeline.save(experiment_name='fasttext_test')
# Out:
# earning_Rate', '--embedding_dim', '$AZUREML_PARAMETER_Embedding_Dim', '--trained_model_dir', '$AZUREML_DATAREFERENCE_Trained_Model_Dir'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'aml-compute', 'dataReferences': {'Training_Data_Dir': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/c2774f44-79a8-4937-9609-1d13eb9c0d3d/Training_Data_Output', 'pathOnCompute': None, 'overwrite': True}, 'Validation_Data_Dir': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/c2774f44-79a8-4937-9609-1d13eb9c0d3d/Validation_Data_Output', 'pathOnCompute': None, 'overwrite': True}, 'Trained_Model_Dir': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/1dbcbdb0-a7d7-4c9b-9a4d-f3940815b374/Trained_Model_Dir', 'pathOnCompute': None, 'overwrite': True}}, 'data': {'Char2_Index_Dir': {'dataLocation': {'dataset': {'id': '9de9b550-46a4-41ce-b1b4-54b6c665fcf3', 'name': None, 'version': None}, 'dataPath': None}, 'mechanism': 'Mount', 'environmentVariableName': 'Char2_Index_Dir', 'pathOnCompute': None, 'overwrite': True}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'Experiment fasttext_test Environment', 'version': 'Autosave_2020-06-17T08:59:22Z_b0145ee7', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['defaults'], 'dependencies': ['python=3.6.6', {'pip': ['--extra-index-url=https://azuremlsdktestpypi.azureedge.net/CLI-SDK-Runners-Validation/15587761', 'azureml-defaults==0.1.0.15587761', 'azureml-pipeline-wrapper==0.1.0.15587761', 'torch==1.4.0', 'scikit-learn', 'tqdm']}], 'name': 'azureml_bfe9579f8051e70e1e6a7a7f61593161'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'AZUREML_PARAMETER_Epochs': '1', 'AZUREML_PARAMETER_Batch_Size': '64', 'AZUREML_PARAMETER_Learning_Rate': '0.0005', 'AZUREML_PARAMETER_Embedding_Dim': '128'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'sharedVolumes': False, 'shmSize': '1g'}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': False, 'directoriesToWatch': ['logs']}, 'spark': {'configuration': {}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'tensorflow': {'workerCount': 0, 'parameterServerCount': 0}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'None'}, 'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'itpCompute': {'configuration': {}}, 'cmAksCompute': {'configuration': {}}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_a921f95d3c3fac7b3def13db2d86448b03b27ab1db14d664dccdf509cdc2cc28_d.txt': 'https://fundamental35269596308.blob.core.windows.net/azureml/ExperimentRun/dcid.1dbcbdb0-a7d7-4c9b-9a4d-f3940815b374/azureml-logs/55_azureml-execution-tvmps_a921f95d3c3fac7b3def13db2d86448b03b27ab1db14d664dccdf509cdc2cc28_d.txt?sv=2019-02-02&sr=b&sig=mRR%2FHF%2BQdVYT92Y4pCQRWcO0RHdRT%2BjvlZKjcWFIH1c%3D&st=2020-06-21T08%3A24%3A27Z&se=2020-06-21T16%3A34%3A27Z&sp=r', 'azureml-logs/65_job_prep-tvmps_a921f95d3c3fac7b3def13db2d86448b03b27ab1db14d664dccdf509cdc2cc28_d.txt': 'https://fundamental35269596308.blob.core.windows.net/azureml/ExperimentRun/dcid.1dbcbdb0-a7d7-4c9b-9a4d-f3940815b374/azureml-logs/65_job_prep-tvmps_a921f95d3c3fac7b3def13db2d86448b03b27ab1db14d664dccdf509cdc2cc28_d.txt?sv=2019-02-02&sr=b& ...
#
#
#
#
# StepRunId: 1d8c78dd-4ccd-4ae4-ae42-60906048780f
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/fasttext_test/runs/1d8c78dd-4ccd-4ae4-ae42-60906048780f?wsid=/subscriptions/4f455bd0-f95a-4b7d-8d08-078611508e0b/resourcegroups/fundamental/workspaces/fundamental3
# StepRun( FastText Test ) Status: NotStarted
# StepRun( FastText Test ) Status: Queued
#
# Streaming azureml-logs/55_azureml-execution-tvmps_a921f95d3c3fac7b3def13db2d86448b03b27ab1db14d664dccdf509cdc2cc28_d.txt
# ========================================================================================================================
# 2020-06-21T08:34:46Z Starting output-watcher...
# 2020-06-21T08:34:46Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# f7b38c0985a569b1089ae491987c1f06dc951fdec2596064f0130df66d9a572e
# StepRun( FastText Test ) Status: Running
#
# Streaming azureml-logs/65_job_prep-tvmps_a921f95d3c3fac7b3def13db2d86448b03b27ab1db14d664dccdf509cdc2cc28_d.txt
# ===============================================================================================================
# Entering job preparation. Current time:2020-06-21T08:34:48.280479
# Starting job preparation. Current time:2020-06-21T08:34:48.879356
# Extracting the control code.
# fetching and extracting the control code on master node.
# Retrieving project from snapshot: 1cd6e247-5155-4fac-ad70-decbc46972c4
# Starting the daemon thread to refresh tokens in background for process with pid = 50
# Starting project file download.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# Entering context manager injector. Current time:2020-06-21T08:35:06.812457
# Initialize DatasetContextManager.
# Starting the daemon thread to refresh tokens in background for process with pid = 105
# Set Dataset Char2_Index_Dir's target path to /tmp/tmp5lq41oyq
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==0.1.0.15587761 azureml-dataprep==1.6.3
# Processing 'Char2_Index_Dir'
# Processing dataset FileDataset
# {
#   "source": [
#     "https://datastore4fasttext.blob.core.windows.net/mytest3/character2index.json"
#   ],
#   "definition": [
#     "GetFiles"
#   ],
#   "registration": {
#     "id": "9de9b550-46a4-41ce-b1b4-54b6c665fcf3",
#     "name": "Char2Index_JSON",
#     "version": 1,
#     "description": "The mapping relationship between character and index ",
#     "workspace": "Workspace.create(name='fundamental3', subscription_id='4f455bd0-f95a-4b7d-8d08-078611508e0b', resource_group='fundamental')"
#   }
# }
# Mounting Char2_Index_Dir to /tmp/tmp5lq41oyq
# Mounted Char2_Index_Dir to /tmp/tmp5lq41oyq
# Exit __enter__ of DatasetContextManager
# Preparing to call script [ fasttext_test.py ] with arguments: ['--trained_model_dir', '/mnt/batch/tasks/shared/LS_root/jobs/fundamental3/azureml/1d8c78dd-4ccd-4ae4-ae42-60906048780f/mounts/workspaceblobstore/azureml/1dbcbdb0-a7d7-4c9b-9a4d-f3940815b374/Trained_Model_Dir', '--test_data_dir', '/mnt/batch/tasks/shared/LS_root/jobs/fundamental3/azureml/1d8c78dd-4ccd-4ae4-ae42-60906048780f/mounts/workspaceblobstore/azureml/c2774f44-79a8-4937-9609-1d13eb9c0d3d/Test_Data_Output', '--char2index_dir', '$Char2_Index_Dir']
# After variable expansion, calling script [ fasttext_test.py ] with arguments: ['--trained_model_dir', '/mnt/batch/tasks/shared/LS_root/jobs/fundamental3/azureml/1d8c78dd-4ccd-4ae4-ae42-60906048780f/mounts/workspaceblobstore/azureml/1dbcbdb0-a7d7-4c9b-9a4d-f3940815b374/Trained_Model_Dir', '--test_data_dir', '/mnt/batch/tasks/shared/LS_root/jobs/fundamental3/azureml/1d8c78dd-4ccd-4ae4-ae42-60906048780f/mounts/workspaceblobstore/azureml/c2774f44-79a8-4937-9609-1d13eb9c0d3d/Test_Data_Output', '--char2index_dir', '/tmp/tmp5lq41oyq/character2index.json']
#
# ============================================
# test_data_dir: /mnt/batch/tasks/shared/LS_root/jobs/fundamental3/azureml/1d8c78dd-4ccd-4ae4-ae42-60906048780f/mounts/workspaceblobstore/azureml/c2774f44-79a8-4937-9609-1d13eb9c0d3d/Test_Data_Output
#
# character to index:   0%|          | 0/38000 [00:00<?, ?it/s]
# character to index:  34%|███▍      | 13078/38000 [00:00<00:00, 130771.39it/s]
# character to index:  51%|█████     | 19367/38000 [00:00<00:00, 98783.04it/s]
# character to index:  87%|████████▋ | 33196/38000 [00:00<00:00, 108041.50it/s]
# character to index: 100%|██████████| 38000/38000 [00:00<00:00, 113854.42it/s]
# /azureml-envs/azureml_bfe9579f8051e70e1e6a7a7f61593161/lib/python3.6/site-packages/torch/serialization.py:593: SourceChangeWarning: source code of class '__main__.FastText' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
#
# Streaming azureml-logs/75_job_post-tvmps_a921f95d3c3fac7b3def13db2d86448b03b27ab1db14d664dccdf509cdc2cc28_d.txt
# ===============================================================================================================
# Entering job release. Current time:2020-06-21T08:35:36.153765
#
# StepRun(FastText Test) Execution Summary
# =========================================
# StepRun( FastText Test ) Status: Finalizing
# {'runId': '1d8c78dd-4ccd-4ae4-ae42-60906048780f', 'target': 'aml-compute', 'status': 'Finalizing', 'startTimeUtc': '2020-06-21T08:34:48.68323Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '1cd6e247-5155-4fac-ad70-decbc46972c4', 'StepType': 'PythonScriptStep', 'azureml.moduleid': '2bb4b42f-9da4-4ffa-b49d-0b8bb6d2af92', 'azureml.pipelinerunid': '6c2dd36e-f6be-4c03-8aac-a901ef2b7a1b', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '9de9b550-46a4-41ce-b1b4-54b6c665fcf3'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'Char2_Index_Dir', 'mechanism': 'Mount'}}], 'outputDatasets': [], 'runDefinition': {'script': 'fasttext_test.py', 'useAbsolutePath': False, 'arguments': ['--trained_model_dir', '$AZUREML_DATAREFERENCE_Trained_Model_Dir', '--test_data_dir', '$AZUREML_DATAREFERENCE_Test_Data_Dir', '--char2index_dir', '$AZUREML_DATAREFERENCE_Char2_Index_Dir'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'aml-compute', 'dataReferences': {'Trained_Model_Dir': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/1dbcbdb0-a7d7-4c9b-9a4d-f3940815b374/Trained_Model_Dir', 'pathOnCompute': None, 'overwrite': True}, 'Test_Data_Dir': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/c2774f44-79a8-4937-9609-1d13eb9c0d3d/Test_Data_Output', 'pathOnCompute': None, 'overwrite': True}}, 'data': {'Char2_Index_Dir': {'dataLocation': {'dataset': {'id': '9de9b550-46a4-41ce-b1b4-54b6c665fcf3', 'name': None, 'version': None}, 'dataPath': None}, 'mechanism': 'Mount', 'environmentVariableName': 'Char2_Index_Dir', 'pathOnCompute': None, 'overwrite': True}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'Experiment fasttext_test Environment', 'version': 'Autosave_2020-06-17T09:01:14Z_955bea81', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['defaults'], 'dependencies': ['python=3.6.6', {'pip': ['--extra-index-url=https://azuremlsdktestpypi.azureedge.net/CLI-SDK-Runners-Validation/15587761', 'azureml-defaults==0.1.0.15587761', 'azureml-pipeline-wrapper==0.1.0.15587761', 'torch==1.4.0', 'scikit-learn', 'tqdm']}], 'name': 'azureml_bfe9579f8051e70e1e6a7a7f61593161'}, 'baseCondaEnvironment': None}, 'environmentVariables': {}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'sharedVolumes': False, 'shmSize': '1g'}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': False, 'directoriesToWatch': ['logs']}, 'spark': {'configuration': {}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'tensorflow': {'workerCount': 0, 'parameterServerCount': 0}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'None'}, 'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'itpCompute': {'configuration': {}}, 'cmAksCompute': {'configuration': {}}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_a921f95d3c3fac7b3def13db2d86448b03b27ab1db14d664dccdf509cdc2cc28_d.txt': 'https://fundamental35269596308.blob.core.windows.net/azureml/ExperimentRun/dcid.1d8c78dd-4ccd-4ae4-ae42-60906048780f/azureml-logs/55_azureml-execution-tvmps_a921f95d3c3fac7b3de ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Completed
# {'runId': '6c2dd36e-f6be-4c03-8aac-a901ef2b7a1b', 'status': 'Completed', 'startTimeUtc': '2020-06-21T08:31:32.210886Z', 'endTimeUtc': '2020-06-21T08:35:42.95368Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'Designer', 'runType': 'HTTP', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://fundamental35269596308.blob.core.windows.net/azureml/ExperimentRun/dcid.6c2dd36e-f6be-4c03-8aac-a901ef2b7a1b/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=x8oTXyuX84%2BuMGbWGz7d%2BowqCKswkScDvzu82Qr%2Bnm0%3D&st=2020-06-21T08%3A25%3A45Z&se=2020-06-21T16%3A35%3A45Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://fundamental35269596308.blob.core.windows.net/azureml/ExperimentRun/dcid.6c2dd36e-f6be-4c03-8aac-a901ef2b7a1b/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=uLIOMF7F1b0Wk5FIbOBpndYIzaGfGYTcPH2eU9yEX3s%3D&st=2020-06-21T08%3A25%3A45Z&se=2020-06-21T16%3A35%3A45Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://fundamental35269596308.blob.core.windows.net/azureml/ExperimentRun/dcid.6c2dd36e-f6be-4c03-8aac-a901ef2b7a1b/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=Smbx8iTq%2Fet%2FhLUzE0kFypN6nJZ%2BJ7MdKzjHkf1OOik%3D&st=2020-06-21T08%3A25%3A45Z&se=2020-06-21T16%3A35%3A45Z&sp=r'}}
# <table style="width:100%"><tr><th>Name</th><th>Id</th><th>Details page</th><th>Pipeline type</th><th>Updated on</th><th>Created by</th><th>Tags</th></tr><tr><td>Pipeline-Created-on-6-21-2020</td><td>97d5550f-cc73-44a7-947c-e83888a5f818</td><td><a href="https://ml.azure.com/visualinterface/authoring/Normal/97d5550f-cc73-44a7-947c-e83888a5f818?wsid=/subscriptions/4f455bd0-f95a-4b7d-8d08-078611508e0b/resourcegroups/fundamental/workspaces/fundamental3" target="_blank" rel="noopener">Link</a></td><td>TrainingPipeline</td><td>June 21, 2020 08:35 AM</td><td>Xiaoyu Yang</td><td><table style="width:100%"><tr><td>azureml.Designer: true</td></tr></table></td></tr></table>
