# %%
from azureml.core import Workspace, Dataset
from azureml.core.compute import AmlCompute, ComputeTarget
from azureml.pipeline.wrapper import Module, dsl, Pipeline
from azureml.core.authentication import InteractiveLoginAuthentication

# %%
subscription_id = '4f455bd0-f95a-4b7d-8d08-078611508e0b'
resource_group = 'fundamental'
workspace_name = 'fundamental3'
tenant_id="72f988bf-86f1-41af-91ab-2d7cd011db47"
# for loading module
namespace=workspace_name
interactive_auth = InteractiveLoginAuthentication(tenant_id=tenant_id)
workspace = Workspace(subscription_id, resource_group, workspace_name)
print(workspace.name, workspace.resource_group, workspace.location, workspace.subscription_id, workspace.compute_targets.keys(),sep = '\n')
# Out:
# fundamental3
# fundamental
# eastasia
# 4f455bd0-f95a-4b7d-8d08-078611508e0b
# dict_keys(['myaks2', 'aml-compute', 'my-compute', 'compute-deploy'])

# %%
aml_compute_name = 'aml-compute'
try:
    aml_compute = AmlCompute(workspace, aml_compute_name)
    print("Found existing compute target: {}".format(aml_compute_name))
except:
    print("Creating new compute target: {}".format(aml_compute_name))

    provisioning_config = AmlCompute.provisioning_configuration(vm_size="STANDARD_D2_V2", min_nodes=1, max_nodes=4)
    aml_compute = ComputeTarget.create(workspace, aml_compute_name, provisioning_config)
    aml_compute.wait_for_completion(show_output=True, min_node_count=None, timeout_in_minutes=20)
# Out:
# Found existing compute target: aml-compute

# %%
# load data
dataset_name = "THUNews"
char2index_name = 'CharToIndex'
if dataset_name not in workspace.datasets:
    web_path = ['https://datastore4fasttext.blob.core.windows.net/data/dataset/']
    data = Dataset.File.from_files(path=web_path)
    data.register(workspace=workspace, name=dataset_name,description='THUCNews dataset is generated by filtering \
    and filtering historical data of Sina News RSS subscription channel from 2005 to 2011', create_new_version=True)
dataset = workspace.datasets[dataset_name]

if char2index_name not in workspace.datasets:
    print('Registering CharToIndex for fasttext pipeline ...')
    path = ['https://datastore4fasttext.blob.core.windows.net/data/map/']
    data = Dataset.File.from_files(path=path)
    data.register(workspace=workspace, name=char2index_name, description='The mapping relationship between character and index ')
    print('Registerd')
char2index = workspace.datasets[char2index_name]

# %%
# load module from yaml
split_data_txt_module_func = Module.from_yaml(workspace, 'split_data_txt/split_data_txt.spec.yaml')
fasttext_train_module_func = Module.from_yaml(workspace, 'fasttext_train/fasttext_train.spec.yaml')
fasttext_evaluation_module_func = Module.from_yaml(workspace, 'fasttext_evaluation/fasttext_evaluation.spec.yaml')
fasttext_score_module_func = Module.from_yaml(workspace, 'fasttext_score/fasttext_score.spec.yaml')
compare_two_models_module_func = Module.from_yaml(workspace, 'compare_two_models/compare_two_models.spec.yaml')

# %%
@dsl.pipeline(name='training_pipeline', description='A sub pipeline including data processing/train/score', default_compute_target=aml_compute_name)
def training_pipeline(epochs):
    split_data_txt = split_data_txt_module_func(
    input_dir = dataset,
    training_data_ratio = 0.1,
    validation_data_ratio = 0.2
    )
    fasttext_train = fasttext_train_module_func(
    training_data_dir = split_data_txt.outputs.training_data_output,
    validation_data_dir = split_data_txt.outputs.validation_data_output,
    char2index_dir = char2index,
    epochs = epochs
    )

    fasttext_evaluation = fasttext_evaluation_module_func(
    trained_model_dir = fasttext_train.outputs.trained_model_dir,
    test_data_dir = split_data_txt.outputs.test_data_output,
    char2index_dir = char2index
    )

    return {**fasttext_evaluation.outputs, **fasttext_train.outputs}

# %%
@dsl.pipeline(name='dummy_automl_pipeline', description='A dummy pipeline that trains two models and output the better one', default_compute_target=aml_compute_name)
def dummy_automl_pipeline():
    sentence = '受疫情影响, 很多学生不得不在家上课'
    train_and_evalute_model1 = training_pipeline(epochs=1)
    train_and_evalute_model2 = training_pipeline(epochs=2)
    compare = compare_two_models_module_func(
        first_trained_model=train_and_evalute_model1.outputs.trained_model_dir,
        first_trained_result=train_and_evalute_model1.outputs.model_testing_result,
        second_trained_model=train_and_evalute_model2.outputs.trained_model_dir,
        second_trained_result=train_and_evalute_model2.outputs.model_testing_result
    )

    fasttext_score = fasttext_score_module_func(
        input_sentence =  sentence,
        fasttext_model_dir = compare.outputs.the_better_model,
        char2index_dir = char2index
    )
    return {**compare.outputs, **fasttext_score.outputs}

# %%
# pipeline
pipeline = dummy_automl_pipeline()
pipeline.save(experiment_name='fasttext_with_one_training_process')
# Out:
# <table style="width:100%"><tr><th>Name</th><th>Id</th><th>Details page</th><th>Pipeline type</th><th>Updated on</th><th>Created by</th><th>Tags</th></tr><tr><td>dummy_automl_pipeline</td><td>6c374326-2044-4e95-a531-9a01e0597349</td><td><a href="https://ml.azure.com/visualinterface/authoring/Normal/6c374326-2044-4e95-a531-9a01e0597349?wsid=/subscriptions/4f455bd0-f95a-4b7d-8d08-078611508e0b/resourcegroups/fundamental/workspaces/fundamental3" target="_blank" rel="noopener">Link</a></td><td>TrainingPipeline</td><td>August 06, 2020 02:23 PM</td><td>Xiaoyu Yang</td><td><table style="width:100%"><tr><td>azureml.Designer: true</td></tr></table></td></tr></table>

# %%
type(pipeline)
# Out:
# azureml.pipeline.wrapper._pipeline.Pipeline

# %%
# validate
# pipeline.validate()
# Out:
# ValidateView(container_id='container_id_ac557a59-0070-418f-a2c9-ff7f71d92964_widget', env_json='{"subscription…
#         <style>
#         #container_id_ac557a59-0070-418f-a2c9-ff7f71d92964_script svg.react-dag-editor-svg-container {
#             height: 800px;
#         }
#         </style>
#         <div id="container_id_ac557a59-0070-418f-a2c9-ff7f71d92964_script"></div>
#         <script>
#             (function () {
#                 if (!window._renderLock) {
#                     window._renderLock = {}
#                 }
#                 if (window._renderLock["ac557a59-0070-418f-a2c9-ff7f71d92964"]) {
#                     return
#                 }
#                 window._renderLock["ac557a59-0070-418f-a2c9-ff7f71d92964"] = "script"
#                 console.log("load as script", Date.now())
#                 window.render_container_id="container_id_ac557a59-0070-418f-a2c9-ff7f71d92964_script";
#                 window.graph_json={"pipeline": {"name": ["dummy_automl_pipeline"], "data_references": {"THUNews": {"dataset_id": "c3a6be90-b3d0-428e-8e5b-5310aae05347"}, "CharToIndex": {"dataset_id": "57995764-b6f2-4975-bf44-99095c8ad82b"}}, "steps": {"18e7a771": {"inputs": {"Input_dir": {"source": "THUNews"}}, "outputs": {"Training_data_output": {"destination": "5947f973-6b41-47f4-8a38-3d4c213fb957_Training_data_output"}, "Validation_data_output": {"destination": "5947f973-6b41-47f4-8a38-3d4c213fb957_Validation_data_output"}, "Test_data_output": {"destination": "5947f973-6b41-47f4-8a38-3d4c213fb957_Test_data_output"}}, "module": {"id": "8eb98b77-2feb-46b6-93f0-f7b5025b6c54", "version": "0.0.40"}, "parameters": {"training_data_ratio": 0.1, "validation_data_ratio": 0.2, "random_split": "False", "seed": "0"}, "validate": {"error": [], "module_id": "8eb98b77-2feb-46b6-93f0-f7b5025b6c54", "namespace": "fundamental3", "module_name": "Split Data Txt", "module_version": "0.0.40"}}, "1deb002f": {"inputs": {"Training_data_dir": {"source": "5947f973-6b41-47f4-8a38-3d4c213fb957_Training_data_output"}, "Validation_data_dir": {"source": "5947f973-6b41-47f4-8a38-3d4c213fb957_Validation_data_output"}, "Char2index_dir": {"source": "CharToIndex"}}, "outputs": {"Trained_model_dir": {"destination": "8801a9f5-cfee-46ce-ad22-1ee7c7a83108_Trained_model_dir"}}, "module": {"id": "cead2c71-cce9-4802-a1d5-1abaa18f0f8d", "version": "0.0.39"}, "parameters": {"epochs": 1, "batch_size": "64", "learning_rate": "0.0005", "embedding_dim": "128"}, "validate": {"error": [], "module_id": "cead2c71-cce9-4802-a1d5-1abaa18f0f8d", "namespace": "fundamental3", "module_name": "FastText Train", "module_version": "0.0.39"}}, "276f088e": {"inputs": {"Trained_model_dir": {"source": "8801a9f5-cfee-46ce-ad22-1ee7c7a83108_Trained_model_dir"}, "Test_data_dir": {"source": "5947f973-6b41-47f4-8a38-3d4c213fb957_Test_data_output"}, "Char2index_dir": {"source": "CharToIndex"}}, "outputs": {"Model_testing_result": {"destination": "6d423541-a5ec-4b24-a041-191bcbddb83e_Model_testing_result"}}, "module": {"id": "700f1135-17bd-4750-bc14-68c476529d1e", "version": "0.0.6"}, "parameters": {}, "validate": {"error": [], "module_id": "700f1135-17bd-4750-bc14-68c476529d1e", "namespace": "fundamental3", "module_name": "FastText Evaluation", "module_version": "0.0.6"}}, "d34d85cb": {"inputs": {"Input_dir": {"source": "THUNews"}}, "outputs": {"Training_data_output": {"destination": "dfe8523c-5000-48c8-8b9e-860f14703da0_Training_data_output"}, "Validation_data_output": {"destination": "dfe8523c-5000-48c8-8b9e-860f14703da0_Validation_data_output"}, "Test_data_output": {"destination": "dfe8523c-5000-48c8-8b9e-860f14703da0_Test_data_output"}}, "module": {"id": "8eb98b77-2feb-46b6-93f0-f7b5025b6c54", "version": "0.0.40"}, "parameters": {"training_data_ratio": 0.1, "validation_data_ratio": 0.2, "random_split": "False", "seed": "0"}, "validate": {"error": [], "module_id": "8eb98b77-2feb-46b6-93f0-f7b5025b6c54", "namespace": "fundamental3", "module_name": "Split Data Txt", "module_version": "0.0.40"}}, "fa14db96": {"inputs": {"Training_data_dir": {"source": "dfe8523c-5000-48c8-8b9e-860f14703da0_Training_data_output"}, "Validation_data_dir": {"source": "dfe8523c-5000-48c8-8b9e-860f14703da0_Validation_data_output"}, "Char2index_dir": {"source": "CharToIndex"}}, "outputs": {"Trained_model_dir": {"destination": "033d005d-ef22-47c0-bcc7-00f662974963_Trained_model_dir"}}, "module": {"id": "cead2c71-cce9-4802-a1d5-1abaa18f0f8d", "version": "0.0.39"}, "parameters": {"epochs": 2, "batch_size": "64", "learning_rate": "0.0005", "embedding_dim": "128"}, "validate": {"error": [], "module_id": "cead2c71-cce9-4802-a1d5-1abaa18f0f8d", "namespace": "fundamental3", "module_name": "FastText Train", "module_version": "0.0.39"}}, "58b5d96d": {"inputs": {"Trained_model_dir": {"source": "033d005d-ef22-47c0-bcc7-00f662974963_Trained_model_dir"}, "Test_data_dir": {"source": "dfe8523c-5000-48c8-8b9e-860f14703da0_Test_data_output ...
# {'result': 'validation passed', 'errors': []}

# %%
# pipeline_run
pipeline_run = pipeline.submit(experiment_name='fasttext_with_two_training_process', regenerate_outputs=True)
# pipeline_run.wait_for_completion()
# Out:
# Submitted PipelineRun 0be4bb33-3b5f-41eb-9f51-6657813ad35a
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/fasttext_with_two_training_process/runs/0be4bb33-3b5f-41eb-9f51-6657813ad35a?wsid=/subscriptions/4f455bd0-f95a-4b7d-8d08-078611508e0b/resourcegroups/fundamental/workspaces/fundamental3
