# %%
import inspect
from azureml.core import Workspace, Dataset
from azureml.core.compute import AmlCompute, ComputeTarget
from azureml.pipeline.core.graph import DataType
from azureml.pipeline.wrapper import Module, dsl, Pipeline
from azureml.core.authentication import InteractiveLoginAuthentication

# %%
subscription_id = '4f455bd0-f95a-4b7d-8d08-078611508e0b'
resource_group = 'fundamental'
workspace_name = 'fundamental3'
namespace=workspace_name # for loading module
# set this if you have multiple tenant
tenant_id="72f988bf-86f1-41af-91ab-2d7cd011db47"
interactive_auth = InteractiveLoginAuthentication(tenant_id=tenant_id)

workspace = Workspace(subscription_id, resource_group, workspace_name)
print(workspace.name, workspace.resource_group, workspace.location, workspace.subscription_id, workspace.compute_targets.keys(),sep = '\n')
# Out:
# Performing interactive authentication. Please follow the instructions on the terminal.
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code GBER2TA92 to authenticate.
# Interactive authentication successfully completed.
# fundamental3
# fundamental
# eastasia
# 4f455bd0-f95a-4b7d-8d08-078611508e0b
# dict_keys(['aml-compute'])

# %%
print(workspace.compute_targets)
aml_compute_name = 'aml-compute'
try:
    aml_compute = AmlCompute(workspace, aml_compute_name)
    print("Found existing compute target: {}".format(aml_compute_name))
except:
    print("Creating new compute target: {}".format(aml_compute_name))

    provisioning_config = AmlCompute.provisioning_configuration(vm_size="STANDARD_D2_V2",
                                                                min_nodes=1,
                                                                max_nodes=4)
    aml_compute = ComputeTarget.create(workspace, aml_compute_name, provisioning_config)
    aml_compute.wait_for_completion(show_output=True, min_node_count=None, timeout_in_minutes=20)
print(aml_compute)
# Out:
# {'aml-compute': AmlCompute(workspace=Workspace.create(name='fundamental3', subscription_id='4f455bd0-f95a-4b7d-8d08-078611508e0b', resource_group='fundamental'), name=aml-compute, id=/subscriptions/4f455bd0-f95a-4b7d-8d08-078611508e0b/resourceGroups/fundamental/providers/Microsoft.MachineLearningServices/workspaces/fundamental3/computes/aml-compute, type=AmlCompute, provisioning_state=Succeeded, location=eastasia, tags=None)}
# Found existing compute target: aml-compute
# AmlCompute(workspace=Workspace.create(name='fundamental3', subscription_id='4f455bd0-f95a-4b7d-8d08-078611508e0b', resource_group='fundamental'), name=aml-compute, id=/subscriptions/4f455bd0-f95a-4b7d-8d08-078611508e0b/resourceGroups/fundamental/providers/Microsoft.MachineLearningServices/workspaces/fundamental3/computes/aml-compute, type=AmlCompute, provisioning_state=Succeeded, location=eastasia, tags=None)

# %%
# register my own datatype
DataType.create_data_type(workspace, 'MyDirectory', description='', is_directory=True) # won't register repeatedly
DataType.create_data_type(workspace, 'MyFile', description='', is_directory=False)

# %%
# load data
dataset_name = 'THUCNews_TXT'
char2index_name = 'Char2Index_JSON'

if dataset_name not in workspace.datasets:
    print('Registering a THUCNews dataset for fasttext pipeline ...')
    path = ['https://datastore4fasttext.blob.core.windows.net/mytest3/THUCNews.txt']
    data = Dataset.File.from_files(path=path)
    data.register(workspace=workspace, name=dataset_name, description='THUCNews dataset is generated by filtering and filtering historical data of Sina News RSS subscription channel from 2005 to 2011')
    print('Registerd')
data = workspace.datasets[dataset_name]

if char2index_name not in workspace.datasets:
    print('Registering a Char2Index_JSON for fasttext pipeline ...')
    path = ['https://datastore4fasttext.blob.core.windows.net/mytest3/character2index.json']
    data = Dataset.File.from_files(path=path)
    data.register(workspace=workspace, name=char2index_name, description='The mapping relationship between character and index ')
    print('Registerd')
char2index = workspace.datasets[char2index_name]

print(data)
print(char2index)
# Out:
# FileDataset
# {
#   "source": [
#     "https://datastore4fasttext.blob.core.windows.net/mytest3/THUCNews.txt"
#   ],
#   "definition": [
#     "GetFiles"
#   ],
#   "registration": {
#     "id": "9e16ea04-3074-4f84-8a8c-83adb226c4ae",
#     "name": "THUCNews_TXT",
#     "version": 1,
#     "description": "THUCNews dataset is generated by filtering and filtering historical data of Sina News RSS subscription channel from 2005 to 2011",
#     "workspace": "Workspace.create(name='fundamental3', subscription_id='4f455bd0-f95a-4b7d-8d08-078611508e0b', resource_group='fundamental')"
#   }
# }
# FileDataset
# {
#   "source": [
#     "https://datastore4fasttext.blob.core.windows.net/mytest3/character2index.json"
#   ],
#   "definition": [
#     "GetFiles"
#   ],
#   "registration": {
#     "id": "9de9b550-46a4-41ce-b1b4-54b6c665fcf3",
#     "name": "Char2Index_JSON",
#     "version": 1,
#     "description": "The mapping relationship between character and index ",
#     "workspace": "Workspace.create(name='fundamental3', subscription_id='4f455bd0-f95a-4b7d-8d08-078611508e0b', resource_group='fundamental')"
#   }
# }

# %%
# load module
try:
    split_data_txt_module_func = Module.load(workspace=workspace, namespace=namespace, name='Split Data Txt')
    print('found split_data_txt_module')
except:
    print('not found split_data_txt_module, register it now...')
    yaml_file='split_data_txt/split_data_txt.spec.yaml'
    split_data_txt_module_func = Module.register(workspace=workspace, yaml_file=yaml_file)

try:
    fasttext_train_module_func = Module.load(workspace=workspace, namespace=namespace, name='FastText Train')
    print('found fasttext_train_module')
except:
    print('not found fasttext_train_module, register it now...')
    yaml_file='fasttext_train/fasttext_train.spec.yaml'
    fasttext_train_module_func = Module.register(workspace=workspace, yaml_file=yaml_file)

try:
    fasttext_score_module_func = Module.load(workspace=workspace, namespace=namespace, name='FastText Score')
    print('found fasttext_score_module')
except:
    print('not found fasttext_score_module, register it now...')
    yaml_file='fasttext_score/fasttext_score.spec.yaml'
    fasttext_score_module_func = Module.register(workspace=workspace, yaml_file=yaml_file)

try:
    compare2model_module_func = Module.load(workspace=workspace, namespace=namespace, name='Compare Two Models')
    print('found compare2model_module')
except:
    print('not found compare2model_module, register it now...')
    yaml_file='compare2model/compare2model.spec.yaml'
    compare2model_module_func = Module.register(workspace=workspace, yaml_file=yaml_file)

try:
    fasttext_predict_module_func = Module.load(workspace=workspace, namespace=namespace, name='FastText Predict')
    print('found fasttext_predict_module')
except:
    print('not found fasttext_predict_module, register it now...')
    yaml_file='fasttext_predict_module/fasttext_predict.spec.yaml'
    fasttext_predict_module_func = Module.register(workspace=workspace, yaml_file=yaml_file)

# inspect signature
print(inspect.signature(split_data_txt_module_func))
print(inspect.signature(fasttext_train_module_func))
print(inspect.signature(fasttext_score_module_func))
print(inspect.signature(compare2model_module_func))
print(inspect.signature(fasttext_predict_module_func))
# Out:
# found split_data_txt_module
# found fasttext_train_module
# found fasttext_score_module
# found compare2model_module
# found fasttext_predict_module
# (input_dir: 'Input Dir' = None, training_data_ratio: 'Training Data Ratio' = '0.7', validation_data_ratio: 'Validation Data Ratio' = '0.1', random_split: 'Random Split' = 'False', seed: 'Seed' = '0')
# (training_data_dir: 'Training Data Dir' = None, validation_data_dir: 'Validation Data Dir' = None, char2_index_dir: 'Char2Index Dir' = None, epochs: 'Epochs' = '2', batch_size: 'Batch Size' = '32', learning_rate: 'Learning Rate' = '0.0005', embedding_dim: 'Embedding Dim' = '128')
# (trained_model_dir: 'Trained Model Dir' = None, test_data_dir: 'Test Data Dir' = None, char2_index_dir: 'Char2Index Dir' = None)
# (first_trained_model: 'First Trained Model' = None, first_trained_result: 'First Trained Result' = None, second_trained_model: 'Second Trained Model' = None, second_trained_result: 'Second Trained Result' = None)
# (fasttext_model: 'Fasttext Model' = None, char2_index_dir: 'Char2Index Dir' = None, input_sentence: 'Input Sentence' = 'I like playing football very much')

# %%
# connect module
split_data_txt = split_data_txt_module_func(
    input_dir = data,
    training_data_ratio = 0.7,
    validation_data_ratio = 0.1,
    random_split = False,
    seed = 1
)
print(split_data_txt.outputs)

fasttext_train = fasttext_train_module_func(
    training_data_dir = split_data_txt.outputs.training_data_output,
    validation_data_dir = split_data_txt.outputs.validation_data_output,
    char2_index_dir = char2index,
    epochs = 1,
    batch_size = 64,
    learning_rate = 0.0005,
    embedding_dim = 128
)
print(fasttext_train.outputs)

fasttext_score = fasttext_score_module_func(
    trained_model_dir = fasttext_train.outputs.trained_model_dir,
    test_data_dir = split_data_txt.outputs.test_data_output,
    char2_index_dir = char2index
)
sentence = '受疫情影响, 今年很多学生在家里待了半年'
fasttext_predict = fasttext_predict_module_func(
        input_sentence =  sentence,
        fasttext_model = fasttext_train.outputs.trained_model_dir,
        char2_index_dir = char2index
)
print(fasttext_predict.outputs)
# Out:
# {'training_data_output': <azureml.pipeline.wrapper._module._OutputBuilder object at 0x7ff75d7dac88>, 'validation_data_output': <azureml.pipeline.wrapper._module._OutputBuilder object at 0x7ff75d7fc080>, 'test_data_output': <azureml.pipeline.wrapper._module._OutputBuilder object at 0x7ff75d7fc400>}
# {'trained_model_dir': <azureml.pipeline.wrapper._module._OutputBuilder object at 0x7ff75d7fc5f8>}
# {}

# %%
# pipeline
pipeline = Pipeline(nodes=[split_data_txt, fasttext_train, fasttext_score, fasttext_predict], workspace=workspace, default_compute_target=aml_compute_name)

# %%
# validate
pipeline.validate()
# Out:
# SupportDetectView()
#         <style>
#         #container_id_f90766e4-8599-4346-bc71-c41be51bf5d6 svg.react-dag-editor-svg-container {
#             height: 800px;
#         }
#         </style>
#         <div id="container_id_f90766e4-8599-4346-bc71-c41be51bf5d6"></div>
#         <script>
#             window.render_container_id="container_id_f90766e4-8599-4346-bc71-c41be51bf5d6";
#             window.graph_json={"pipeline": {"name": "Pipeline-Created-on-7-2-2020", "data_references": {"THUCNews_TXT": {"dataset_id": "b2319b6a-338d-4788-adfe-d55ca1db06b7"}, "Char2Index_JSON": {"dataset_id": "01760799-3cea-4885-9d68-04bbd10e3bd9"}}, "steps": {"7f4fc0bc-0d8a-4d1b-b672-8c47a5e36c4c": {"inputs": {"Input_Dir": {"source": "THUCNews_TXT"}}, "outputs": {"Training_Data_Output": {"destination": "7f4fc0bc-0d8a-4d1b-b672-8c47a5e36c4c_Training_Data_Output"}, "Validation_Data_Output": {"destination": "7f4fc0bc-0d8a-4d1b-b672-8c47a5e36c4c_Validation_Data_Output"}, "Test_Data_Output": {"destination": "7f4fc0bc-0d8a-4d1b-b672-8c47a5e36c4c_Test_Data_Output"}}, "module": {"id": "359390d9-d62d-444c-9aae-ea39a7980e72", "version": "0.0.21"}, "validate": {"error": [], "module_id": "359390d9-d62d-444c-9aae-ea39a7980e72", "namespace": "fundamental3", "module_name": "Split Data Txt", "module_version": "0.0.21"}}, "18403d47-00c8-46f8-bf40-5e23f9140cd8": {"inputs": {"Training_Data_Dir": {"source": "7f4fc0bc-0d8a-4d1b-b672-8c47a5e36c4c_Training_Data_Output"}, "Validation_Data_Dir": {"source": "7f4fc0bc-0d8a-4d1b-b672-8c47a5e36c4c_Validation_Data_Output"}, "Char2_Index_Dir": {"source": "Char2Index_JSON"}}, "outputs": {"Trained_Model_Dir": {"destination": "18403d47-00c8-46f8-bf40-5e23f9140cd8_Trained_Model_Dir"}}, "module": {"id": "de6a7b13-ff81-46b9-81e8-01129b2b38b8", "version": "0.0.27"}, "validate": {"error": [], "module_id": "de6a7b13-ff81-46b9-81e8-01129b2b38b8", "namespace": "fundamental3", "module_name": "FastText Train", "module_version": "0.0.27"}}, "727fb3f3-2db9-4296-9a65-af5b9b6bbecf": {"inputs": {"Trained_Model_Dir": {"source": "18403d47-00c8-46f8-bf40-5e23f9140cd8_Trained_Model_Dir"}, "Test_Data_Dir": {"source": "7f4fc0bc-0d8a-4d1b-b672-8c47a5e36c4c_Test_Data_Output"}, "Char2_Index_Dir": {"source": "Char2Index_JSON"}}, "outputs": {"Model_Testing_Result": {"destination": "727fb3f3-2db9-4296-9a65-af5b9b6bbecf_Model_Testing_Result"}}, "module": {"id": "a39765cd-ac73-4a8a-8314-d9679cff5506", "version": "0.0.12"}, "validate": {"error": [], "module_id": "a39765cd-ac73-4a8a-8314-d9679cff5506", "namespace": "fundamental3", "module_name": "FastText Score", "module_version": "0.0.12"}}, "54dd470e-fd3f-4450-b1f5-2f1db7cf46ed": {"inputs": {"Fasttext_Model": {"source": "18403d47-00c8-46f8-bf40-5e23f9140cd8_Trained_Model_Dir"}, "Char2_Index_Dir": {"source": "Char2Index_JSON"}}, "outputs": {}, "module": {"id": "5ac7627b-f849-4fda-a1fd-2cd14a26fb8b", "version": "0.0.18"}, "validate": {"error": [], "module_id": "5ac7627b-f849-4fda-a1fd-2cd14a26fb8b", "namespace": "fundamental3", "module_name": "FastText Predict", "module_version": "0.0.18"}}}}, "subGraphInfo": [{"name": "Pipeline-Created-on-7-2-2020", "description": null, "defaultCompute": "aml-compute", "id": "faf263ee-549c-4fdf-b1d1-183e082abeda", "parentGraphId": null, "inputs": [{"name": "THUCNews_TXT_7f4fc0bc-0d8a-4d1b-b672-8c47a5e36c4c", "external": [], "internal": [{"portName": "Input_Dir", "nodeId": "7f4fc0bc-0d8a-4d1b-b672-8c47a5e36c4c"}]}, {"name": "Char2Index_JSON_18403d47-00c8-46f8-bf40-5e23f9140cd8", "external": [], "internal": [{"portName": "Char2_Index_Dir", "nodeId": "18403d47-00c8-46f8-bf40-5e23f9140cd8"}]}, {"name": "Char2Index_JSON_727fb3f3-2db9-4296-9a65-af5b9b6bbecf", "external": [], "internal": [{"portName": "Char2_Index_Dir", "nodeId": "727fb3f3-2db9-4296-9a65-af5b9b6bbecf"}]}, {"name": "Char2Index_JSON_54dd470e-fd3f-4450-b1f5-2f1db7cf46ed", "external": [], "internal": [{"portName": "Char2_Index_Dir", "nodeId": "54dd470e-fd3f-4450-b1f5-2f1db7cf46ed"}]}], "outputs": []}], "nodeIdToSubGraphIdMapping": {"7f4fc0bc-0d8a-4d1b-b672-8c47a5e36c4c": "faf263ee-549c-4fdf-b1d1-183e082abeda", "18403d47-00c8-46f8-bf40-5e23f9140cd8": "faf263ee-549c-4fdf-b1d1-183e082abeda", "727fb3f3-2db9-4296-9a65-af5b9b6bbecf": "faf263ee-549c-4fdf-b1d1-183e082abeda", "54dd470e-fd3f-4450-b1f5-2f1db7cf46ed": "faf263ee-549c-4fdf-b1d1-183e082abeda"}, "modules": [{"module_id": "359390d9-d62d-444c-9aae-e ...
#             window.env_json={"subscription_id": "4f455bd0-f95a-4b7d-8d08-078611508e0b"};
#             window.before_script = performance.now();
#         </script>
#         <script src="https://yucongj.azureedge.net/libs/prod/0.0.4/index.js"></script>
# {'result': 'validation passed', 'errors': []}

# %%
# run
run = pipeline.submit(experiment_name='fasttext_with_one_training_process')
run.wait_for_completion()
pipeline.save(experiment_name='fasttext_with_one_training_process')
# Out:
# ommunicator': 'None', 'target': 'aml-compute', 'dataReferences': {}, 'data': {'Trained_Model_Dir': {'dataLocation': {'dataset': {'id': '7f6c7f90-baae-4edf-ace6-4434911de674', 'name': None, 'version': None}, 'dataPath': None}, 'mechanism': 'Mount', 'environmentVariableName': 'Trained_Model_Dir', 'pathOnCompute': None, 'overwrite': True}, 'Test_Data_Dir': {'dataLocation': {'dataset': {'id': 'ad6c522e-73ff-4bee-8954-91ca7e4a6be3', 'name': None, 'version': None}, 'dataPath': None}, 'mechanism': 'Mount', 'environmentVariableName': 'Test_Data_Dir', 'pathOnCompute': None, 'overwrite': True}, 'Char2_Index_Dir': {'dataLocation': {'dataset': {'id': '9de9b550-46a4-41ce-b1b4-54b6c665fcf3', 'name': None, 'version': '1'}, 'dataPath': None}, 'mechanism': 'Mount', 'environmentVariableName': 'Char2_Index_Dir', 'pathOnCompute': None, 'overwrite': True}}, 'outputData': {'Model_Testing_Result': {'outputLocation': {'dataset': None, 'dataPath': {'datastoreName': 'workspaceblobstore', 'relativePath': None}}, 'mechanism': 'Upload', 'additionalOptions': {'pathOnCompute': None, 'registrationOptions': {'name': None, 'description': None, 'tags': None, 'datasetRegistrationOptions': {'additionalTransformation': None}}, 'uploadOptions': {'overwrite': True, 'sourceGlobs': {'globPatterns': None}}}}}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'Experiment fasttext_with_one_training_process Environment', 'version': 'Autosave_2020-06-25T09:55:18Z_0d11f66f', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['defaults'], 'dependencies': ['python=3.6.6', {'pip': ['--extra-index-url=https://azuremlsdktestpypi.azureedge.net/CLI-SDK-Runners-Validation/15978945', 'azureml-defaults==0.1.0.15978945', 'azureml-pipeline-wrapper==0.1.0.15978945', 'torch==1.4.0', 'scikit-learn', 'tqdm']}], 'name': 'azureml_7f21c6d98101f8e4acf4f096be9145b8'}, 'baseCondaEnvironment': None}, 'environmentVariables': {}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'sharedVolumes': False, 'shmSize': '1g'}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': False, 'directoriesToWatch': ['logs']}, 'spark': {'configuration': {}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'tensorflow': {'workerCount': 0, 'parameterServerCount': 0}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'None'}, 'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'itpCompute': {'configuration': {}}, 'cmAksCompute': {'configuration': {}}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_3bd55d535a8c89dc3b1cc357c280032c9d93a08814b99f9dd703c5fff7f59851_d.txt': 'https://fundamental35269596308.blob.core.windows.net/azureml/ExperimentRun/dcid.601345a1-d968-46b1-b7e7-2d3909b063aa/azureml-logs/55_azureml-execution-tvmps_3bd55d535a8c89dc3b1cc357c280032c9d93a08814b99f9dd703c5fff7f59851_d.txt?sv=2019-02-02&sr=b&sig=naotdZCh3kr1sRi8cJicCKE8LkE76pY01QOXAvFyxME%3D&st=2020-07-02T01%3A33%3A25Z&se=2020-07-02T09%3A43%3A25Z&sp=r', 'azureml-logs/65_job_prep-tvmps_3bd55d535a8c89dc3b1cc357c280032c9d93a08814b99f9dd703c5fff7f59851_d.txt': 'https://fundamental35269596308.blob.core.windows.net/azureml/ExperimentRun/dcid.601345a1-d968-46b1-b7e7-2d3909b063aa/azureml-logs/65_job_prep-tvmps_3bd55d535a8c89dc3b1cc357c280032c9d93a08814b99f9dd703c5fff7f59851_d.txt?sv=2019-02-02&sr=b&sig=RKn1uB9kHkF9qo74pzBSlT6Ev ...
#
#
#
#
# StepRunId: 4ee01ef4-861d-494c-9dc7-4801faca724d
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/fasttext_with_one_training_process/runs/4ee01ef4-861d-494c-9dc7-4801faca724d?wsid=/subscriptions/4f455bd0-f95a-4b7d-8d08-078611508e0b/resourcegroups/fundamental/workspaces/fundamental3
# StepRun( FastText Predict ) Status: Queued
# StepRun( FastText Predict ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_3bd55d535a8c89dc3b1cc357c280032c9d93a08814b99f9dd703c5fff7f59851_d.txt
# ========================================================================================================================
# 2020-07-02T01:43:35Z Executing 'Copy ACR Details file' on 10.0.0.6
# 2020-07-02T01:43:35Z Starting output-watcher...
# 2020-07-02T01:43:35Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2020-07-02T01:43:35Z Copy ACR Details file succeeded on 10.0.0.6. Output:
# >>>
# >>>
# Login Succeeded
#
# Streaming azureml-logs/65_job_prep-tvmps_3bd55d535a8c89dc3b1cc357c280032c9d93a08814b99f9dd703c5fff7f59851_d.txt
# ===============================================================================================================
# Entering job preparation. Current time:2020-07-02T01:43:39.270428
# Starting job preparation. Current time:2020-07-02T01:43:39.906370
# Extracting the control code.
# fetching and extracting the control code on master node.
# Retrieving project from snapshot: de70667d-f4f1-47ab-8d31-ec268e340829
# Starting the daemon thread to refresh tokens in background for process with pid = 49
# Starting project file download.
# Finished project file download.
# downloadDataStore - Download from datastores if requested.
# Entering context manager injector. Current time:2020-07-02T01:43:42.025542
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# Entering context manager injector. Current time:2020-07-02T01:43:44.228930
# Initialize DatasetContextManager.
# Starting the daemon thread to refresh tokens in background for process with pid = 103
# Set Dataset Fasttext_Model's target path to /tmp/tmpol5ccxdw
# Set Dataset Char2_Index_Dir's target path to /tmp/tmpni2wx_0w
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==0.1.0.15978945 azureml-dataprep==1.8.2. Session id: 19c27cba-9a21-4181-9fd8-83b2882ebda7.
# Processing 'Fasttext_Model'.
# Processing dataset FileDataset
# {
#   "source": [
#     "('workspaceblobstore', 'dataset/48172574-6965-4cb5-a859-ef0fd6124fb0/Trained_Model_Dir/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "7f6c7f90-baae-4edf-ace6-4434911de674",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='fundamental3', subscription_id='4f455bd0-f95a-4b7d-8d08-078611508e0b', resource_group='fundamental')"
#   }
# }
# Mounting Fasttext_Model to /tmp/tmpol5ccxdw.
# Mounted Fasttext_Model to /tmp/tmpol5ccxdw as folder.
# Processing 'Char2_Index_Dir'.
# Processing dataset FileDataset
# {
#   "source": [
#     "https://datastore4fasttext.blob.core.windows.net/mytest3/character2index.json"
#   ],
#   "definition": [
#     "GetFiles"
#   ],
#   "registration": {
#     "id": "9de9b550-46a4-41ce-b1b4-54b6c665fcf3",
#     "name": "Char2Index_JSON",
#     "version": 1,
#     "description": "The mapping relationship between character and index ",
#     "workspace": "Workspace.create(name='fundamental3', subscription_id='4f455bd0-f95a-4b7d-8d08-078611508e0b', resource_group='fundamental')"
#   }
# }
# Mounting Char2_Index_Dir to /tmp/tmpni2wx_0w.
# Mounted Char2_Index_Dir to /tmp/tmpni2wx_0w as single file.
# Exit __enter__ of DatasetContextManager
# Preparing to call script [ fasttext_predict.py ] with arguments: ['--fasttext_model', '$Fasttext_Model', '--char2index_dir', '$Char2_Index_Dir', '--input_sentence', '受疫情影响, 今年很多学生在家里待了半年']
# After variable expansion, calling script [ fasttext_predict.py ] with arguments: ['--fasttext_model', '/tmp/tmpol5ccxdw', '--char2index_dir', '/tmp/tmpni2wx_0w/character2index.json', '--input_sentence', '受疫情影响, 今年很多学生在家里待了半年']
#
# =====================================================
# fasttext_model: /tmp/tmpol5ccxdw
# char2index_dir: /tmp/tmpni2wx_0w/character2index.json
# input_sentence: 受疫情影响, 今年很多学生在家里待了半年
# /mnt/batch/tasks/shared/LS_root/jobs/fundamental3/azureml/4ee01ef4-861d-494c-9dc7-4801faca724d/mounts/workspaceblobstore/azureml/4ee01ef4-861d-494c-9dc7-4801faca724d/utils.py:201: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   samples = np.array(samples)
#
# Streaming azureml-logs/75_job_post-tvmps_3bd55d535a8c89dc3b1cc357c280032c9d93a08814b99f9dd703c5fff7f59851_d.txt
# ===============================================================================================================
# Entering job release. Current time:2020-07-02T01:44:32.298906
#
# StepRun(FastText Predict) Execution Summary
# ============================================
# StepRun( FastText Predict ) Status: Finalizing
# {'runId': '4ee01ef4-861d-494c-9dc7-4801faca724d', 'target': 'aml-compute', 'status': 'Finalizing', 'startTimeUtc': '2020-07-02T01:43:35.011564Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': 'de70667d-f4f1-47ab-8d31-ec268e340829', 'StepType': 'PythonScriptStep', 'azureml.moduleid': '5ac7627b-f849-4fda-a1fd-2cd14a26fb8b', 'azureml.pipelinerunid': '1592fab6-25b4-4669-aabc-ce6435ecd74e', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '7f6c7f90-baae-4edf-ace6-4434911de674'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'Fasttext_Model', 'mechanism': 'Mount'}}, {'dataset': {'id': '9de9b550-46a4-41ce-b1b4-54b6c665fcf3'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'Char2_Index_Dir', 'mechanism': 'Mount'}}], 'outputDatasets': [], 'runDefinition': {'script': 'fasttext_predict.py', 'useAbsolutePath': False, 'arguments': ['--fasttext_model', '$AZUREML_DATAREFERENCE_Fasttext_Model', '--char2index_dir', '$AZUREML_DATAREFERENCE_Char2_Index_Dir', '--input_sentence', '$AZUREML_PARAMETER_Input_Sentence'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'aml-compute', 'dataReferences': {}, 'data': {'Fasttext_Model': {'dataLocation': {'dataset': {'id': '7f6c7f90-baae-4edf-ace6-4434911de674', 'name': None, 'version': None}, 'dataPath': None}, 'mechanism': 'Mount', 'environmentVariableName': 'Fasttext_Model', 'pathOnCompute': None, 'overwrite': True}, 'Char2_Index_Dir': {'dataLocation': {'dataset': {'id': '9de9b550-46a4-41ce-b1b4-54b6c665fcf3', 'name': None, 'version': '1'}, 'dataPath': None}, 'mechanism': 'Mount', 'environmentVariableName': 'Char2_Index_Dir', 'pathOnCompute': None, 'overwrite': True}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'Experiment fasttext_with_one_training_process Environment', 'version': 'Autosave_2020-06-25T09:59:00Z_72c2d873', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['defaults'], 'dependencies': ['python=3.6.6', {'pip': ['--extra-index-url=https://azuremlsdktestpypi.azureedge.net/CLI-SDK-Runners-Validation/15978945', 'azureml-defaults==0.1.0.15978945', 'azureml-pipeline-wrapper==0.1.0.15978945', 'torch==1.4.0', 'scikit-learn', 'tqdm']}], 'name': 'azureml_7f21c6d98101f8e4acf4f096be9145b8'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'AZUREML_PARAMETER_Input_Sentence': '受疫情影响, 今年很多学生在家里待了半年'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'sharedVolumes': False, 'shmSize': '1g'}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': False, 'directoriesToWatch': ['logs']}, 'spark': {'configuration': {}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'tensorflow': {'workerCount': 0, 'parameterServerCount': 0}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'None'}, 'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'itpCompute': {'configuration': {}}, 'cmAksCompute': {'configuration': {}}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_3bd55d535a8c89dc3b1cc357c280032c9d93a08814b99f9dd703c5fff7f59851_d.txt': 'https://fundamental35269596308.blob.core.windows.net/azureml/ExperimentRun/dcid.4ee01ef4-861d- ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Completed
# {'runId': '1592fab6-25b4-4669-aabc-ce6435ecd74e', 'status': 'Completed', 'startTimeUtc': '2020-07-02T01:38:57.496108Z', 'endTimeUtc': '2020-07-02T01:44:41.717868Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'Designer', 'runType': 'HTTP', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://fundamental35269596308.blob.core.windows.net/azureml/ExperimentRun/dcid.1592fab6-25b4-4669-aabc-ce6435ecd74e/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=kltQiWwU5Zai4qZeBhCV4uengFf4FOZLhmfGEEji1ZE%3D&st=2020-07-02T01%3A34%3A43Z&se=2020-07-02T09%3A44%3A43Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://fundamental35269596308.blob.core.windows.net/azureml/ExperimentRun/dcid.1592fab6-25b4-4669-aabc-ce6435ecd74e/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=TN51sMiPwjKIbaSPORpiVrSGkcY%2FYDzIKQYlfL2DBuw%3D&st=2020-07-02T01%3A34%3A43Z&se=2020-07-02T09%3A44%3A43Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://fundamental35269596308.blob.core.windows.net/azureml/ExperimentRun/dcid.1592fab6-25b4-4669-aabc-ce6435ecd74e/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=vdvbjXILorzi%2B%2F4Ld8fGEyChH49U8giT3cz%2FWE6SAr8%3D&st=2020-07-02T01%3A34%3A43Z&se=2020-07-02T09%3A44%3A43Z&sp=r'}}
# <table style="width:100%"><tr><th>Name</th><th>Id</th><th>Details page</th><th>Pipeline type</th><th>Updated on</th><th>Created by</th><th>Tags</th></tr><tr><td>Pipeline-Created-on-7-2-2020</td><td>75347352-e757-467a-8cd1-57544f216da7</td><td><a href="https://ml.azure.com/visualinterface/authoring/Normal/75347352-e757-467a-8cd1-57544f216da7?wsid=/subscriptions/4f455bd0-f95a-4b7d-8d08-078611508e0b/resourcegroups/fundamental/workspaces/fundamental3" target="_blank" rel="noopener">Link</a></td><td>TrainingPipeline</td><td>July 02, 2020 01:44 AM</td><td>Xiaoyu Yang</td><td><table style="width:100%"><tr><td>azureml.Designer: true</td></tr></table></td></tr></table>
